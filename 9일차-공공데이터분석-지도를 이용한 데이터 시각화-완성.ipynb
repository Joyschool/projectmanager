# %% [markdown]
# # [실습] 지도를 이용한 데이터 시각화하기

# %% [markdown]
# ##### [실습] 지도에 우리집 표시하기
# ##### [미션] 여행가고 싶은 장소(국내외) 3곳을 지도에 다른 색상 마커로 표시하기
# ##### [실습-옵션] (나의) 구글 Location History 데이터 지도에 표시하기
# ##### [실습] 우리나라 행정구역 경계 지도에 표시하기
# ##### [실습] 서울지역 구별 인구수 지도에 시각화하기
# ##### [미션] 제주도 지역별 인구수 지도에 시각화하기

# %% [markdown]
# -------------------------------

# %% [markdown]
# ### 지도에 표시하기 위해 필요한 정보
# - **위도(Latitude)**: 가로선, 적도를 기준으로 북쪽/남쪽으로 얼마나 떨어져 있는지 나타내는 위치, 위도 1도는 대략 111km,
# - **경도(longitude)**: 세로선, 그리니치 천문대를 기준으로 동/서를 세로로 표시하는 선, 오른쪽 동경(East~180)/왼쪽 서경(West~180)

# %%
# 인터넷에 있는 이미지 보여주기
from IPython.display import Image
Image(url='http://4.bp.blogspot.com/-7nTuhDQ2gSE/VYgQiE8sJzI/AAAAAAAAALw/JFVQKIhZyF4/s1600/This_is_a_basic_photo_showing_that_latitude_lines_are_horizontal_and_longitude_lines_are_vertical-_2014-07-25_20-36.jpg'
     , width=400, height=300)
# Out:
# <img src="http://4.bp.blogspot.com/-7nTuhDQ2gSE/VYgQiE8sJzI/AAAAAAAAALw/JFVQKIhZyF4/s1600/This_is_a_basic_photo_showing_that_latitude_lines_are_horizontal_and_longitude_lines_are_vertical-_2014-07-25_20-36.jpg" width="400" height="300"/>

# %% [markdown]
# - **우리나라의 위도 경도 **
# > 위도(33 ~ 43), 경도(124 ~ 132)

# %%
Image(url='https://mblogthumb-phinf.pstatic.net/MjAxOTA3MTJfMTgg/MDAxNTYyOTAxMzQ0MzE0.KPkhwGuXiIxf5gKHa28kdazfvAFi8x_8pYqQf5wCgIIg.bFcsxsI-MmUaKUW_zBJWhCE6Z7mbbaI4z7a7NW6G2wog.PNG.lkokvse78/image.png?type=w800'
          , width=400, height=300)
# Out:
# <img src="https://mblogthumb-phinf.pstatic.net/MjAxOTA3MTJfMTgg/MDAxNTYyOTAxMzQ0MzE0.KPkhwGuXiIxf5gKHa28kdazfvAFi8x_8pYqQf5wCgIIg.bFcsxsI-MmUaKUW_zBJWhCE6Z7mbbaI4z7a7NW6G2wog.PNG.lkokvse78/image.png?type=w800" width="400" height="300"/>

# %% [markdown]
# --------------

# %% [markdown]
# ### [실습] 지도에 우리집 표시하기

# %% [markdown]
# #### 지도 라이브러리
# - 공식 사이트: https://python-visualization.github.io/folium/
# - 참고 사이트: https://teddylee777.github.io/visualization/folium
# - 참고 사이트: https://dailyheumsi.tistory.com/m/144?category=854906

# %% [markdown]
# #### 1. 지도 라이브러리 folium 설치

# %%
# !pip install folium

# %%
import folium

folium.__version__

# %% [markdown]
# #### 2. 우리집 주소 지도에 표시하기
# - 구글 지도 또는 네이버 지도 등에서 우리집 위도&경도 값 확인하기
# - **지도 테마(종류**:  (기본테마)OpenStreetMap, Stamen Terrain, Stamen Toner, cartodbpositron
#  > tile 옵션 사용하여 적용: ex(tiles='Stamen Toner') <br>
#  >‘Mapbox Bright’, 와 ‘Mapbox Control room tiles’ 은 등록키가 있어야함.
#
# - **location**: 마커를 추가할 위도/경도 좌표를 입력 후
#
# - **popup**: 표기할 팝업 문구 지정 (마우스 클릭시 표기되는 문구)
#
# - **tooltip**: 표기할 툴팁 지정 (마우스 오버시 표기되는 문구)
#
# #### # 마커 종류
# - icon : star/cloud/info-sign/
# - color : red/blue/green/등

# %%
import folium

#------------------
# 우리집 [위도,경도]=[Latitude, longitude]
#------------------
# 방법1 : location에 직접 넣기
m = folium.Map(location=[37.5393556, 127.0667081],
               zoom_start=16)

# 방법2 : 딕셔너리 정보 이용해서 넣기
data = {'우리집': [37.5393556, 127.0667081] }
m = folium.Map(location=data['우리집'], zoom_start=16)


#------------------
# 지도 종류 변경하기
#------------------
m = folium.Map(location=data['우리집'], zoom_start=16, tiles='OpenStreetMap')

#------------------
# 마커 표시하기
#------------------
folium.Marker(location = data['우리집'],
              popup = '동부여성발전센터', 
              icon=folium.Icon(color='purple', icon='star')
).add_to(m)


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ed94eba099135d2cbe0839da258d7f35 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ed94eba099135d2cbe0839da258d7f35&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_ed94eba099135d2cbe0839da258d7f35 = L.map(
#                 &quot;map_ed94eba099135d2cbe0839da258d7f35&quot;,
#                 {
#                     center: [37.5393556, 127.0667081],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6c29cc052481d56993d07fc03684d0dc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ed94eba099135d2cbe0839da258d7f35);
#
#
#             var marker_466356e2d6d048118a7da636c1b0447f = L.marker(
#                 [37.5393556, 127.0667081],
#                 {}
#             ).addTo(map_ed94eba099135d2cbe0839da258d7f35);
#
#
#             var icon_af30862bf57c7ff178974d86abc87726 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_466356e2d6d048118a7da636c1b0447f.setIcon(icon_af30862bf57c7ff178974d86abc87726);
#
#
#         var popup_0810fae4b0b3c15ec567414c7b4d2b67 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_c95a2d08f8b8f13857ca6c416cfa44eb = $(`&lt;div id=&quot;html_c95a2d08f8b8f13857ca6c416cfa44eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;동부여성발전센터&lt;/div&gt;`)[0];
#             popup_0810fae4b0b3c15ec567414c7b4d2b67.setContent(html_c95a2d08f8b8f13857ca6c416cfa44eb);
#
#
#         marker_466356e2d6d048118a7da636c1b0447f.bindPopup(popup_0810fae4b0b3c15ec567414c7b4d2b67)
#         ;
#
#
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### 3. 우리 집 반경에 CircleMarker 표시하기
# - location Point [위도, 경도] 를 중심으로 radius 만큼의 원을 그린다

# %%
import folium

data = {'우리집': [37.5393556, 127.0667081] }
m = folium.Map(location=data['우리집'], zoom_start=16)

folium.Marker(location = data['우리집'],
              popup = '동부여성발전센터', 
              icon=folium.Icon(color='red', icon='star')
).add_to(m)


# 방법1: CircleMarker 색칠 안하기
folium.CircleMarker(
    location= data['우리집'],
    radius = 100,      # 원 크기
    fill=False,         # 원 칠하기
    color='#3366ff',   # 원 선 색상
    popup='CircleMarker popup',
    tooltip = '우리집'
).add_to(m)

# 방법2: CircleMarker 색칠하기 
# folium.CircleMarker(
#     location= data['우리집'],
#     radius = 100,      # 원 크기
#     fill=True,         # 원 칠하기
#     color='#3366ff',   # 원 선 색상
#     fill_color='#ff3366', # 원 내부 색상
#     popup='CircleMarker popup',
#     tooltip = '우리집'
# ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_46617afca202bc00eeb19d7c4bf19c1d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_46617afca202bc00eeb19d7c4bf19c1d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_46617afca202bc00eeb19d7c4bf19c1d = L.map(
#                 &quot;map_46617afca202bc00eeb19d7c4bf19c1d&quot;,
#                 {
#                     center: [37.5393556, 127.0667081],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_990ae565509c3ebe282814eee9804579 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_46617afca202bc00eeb19d7c4bf19c1d);
#
#
#             var marker_884f31c25fa0106f7192b3104e13f945 = L.marker(
#                 [37.5393556, 127.0667081],
#                 {}
#             ).addTo(map_46617afca202bc00eeb19d7c4bf19c1d);
#
#
#             var icon_6a329355f677494e6e2496fce0abef41 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_884f31c25fa0106f7192b3104e13f945.setIcon(icon_6a329355f677494e6e2496fce0abef41);
#
#
#         var popup_c16d87a897c1c4f7a08b46d433dca659 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_d32939a6bb33990b06eff20bb1bb22c3 = $(`&lt;div id=&quot;html_d32939a6bb33990b06eff20bb1bb22c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;동부여성발전센터&lt;/div&gt;`)[0];
#             popup_c16d87a897c1c4f7a08b46d433dca659.setContent(html_d32939a6bb33990b06eff20bb1bb22c3);
#
#
#         marker_884f31c25fa0106f7192b3104e13f945.bindPopup(popup_c16d87a897c1c4f7a08b46d433dca659)
#         ;
#
#
#
#
#             var circle_marker_52a11b80a6223527e817f527a795da93 = L.circleMarker(
#                 [37.5393556, 127.0667081],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3366ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3366ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 100, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_46617afca202bc00eeb19d7c4bf19c1d);
#
#
#         var popup_acc31b7ef9c0e5a96ce10ddd4c497052 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_3e1780bdcb248c845995cb2fcb98cfe5 = $(`&lt;div id=&quot;html_3e1780bdcb248c845995cb2fcb98cfe5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CircleMarker popup&lt;/div&gt;`)[0];
#             popup_acc31b7ef9c0e5a96ce10ddd4c497052.setContent(html_3e1780bdcb248c845995cb2fcb98cfe5);
#
#
#         circle_marker_52a11b80a6223527e817f527a795da93.bindPopup(popup_acc31b7ef9c0e5a96ce10ddd4c497052)
#         ;
#
#
#
#
#             circle_marker_52a11b80a6223527e817f527a795da93.bindTooltip(
#                 `&lt;div&gt;
#                      우리집
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### 4. html 파일로 저장하기

# %%
import webbrowser

# html 파일로 저장하기
m.save('data/map_myhouse.html')
webbrowser.open('c:/python/projectmanager/data/map_myhouse.html') # fullpath를 사용해야 오류가 없다
# Out:
# True

# %% [markdown]
# ------------------------------------------------

# %% [markdown]
# ### [미션] 여행가고 싶은 장소(국내외) 3곳을 지도에 다른 색상 마커로 표시하기
#
# - 영국-내셔널 갤러리: 51.508929,-0.128299
# - 뉴욕-브로드웨이: 40.8124199,-73.9627283
# - 로마-트레비 분수: 41.9010333,12.4810789
# - tiles='Mapbox'
# > - Stamen Terrain: 녹색 지도
# > - Stamen Toner: 흑백 토너

# %%
buckets = {'영국-내셔널 갤러리': [51.508929,-0.128299],
           '뉴욕-브로드웨이': [40.8124199,-73.9627283],
           '로마-트레비 분수': [41.9010333,12.4810789],
          }

m = folium.Map(location= [41.9010333, 12.4810789], 
               zoom_start=2, 
               tiles='Stamen Toner')  

folium.Marker(location= buckets['영국-내셔널 갤러리'],
              icon=folium.Icon(icon='glyphicon glyphicon-thumbs-up',
                                   color='purple', icon_color='white',),
              popup='영국-내셔널 갤러리',
              tooltip = '1st travel'
).add_to(m)
folium.Marker(location= buckets['뉴욕-브로드웨이'],
              icon=folium.Icon(icon='info-sign', color='green'),
              popup='뉴욕 브로드웨이',
              tooltip = '2nd travel'
).add_to(m)
folium.Marker(location= buckets['로마-트레비 분수'],
              icon=folium.Icon(icon='cloud', color='red'),
              popup='로마 트레비 분수',
              tooltip = '3rd travel'
).add_to(m)

m.save('data/map_mytravel.html')
webbrowser.open('c:/python/highschool/data/map_mytravel.html') # fullpath를 사용해야 오류가 없다

# %% [markdown]
# ----------------------

# %% [markdown]
# --------------

# %% [markdown]
# ### [실습] (나의) 구글 Location History 데이터 지도에 표시하기
#
# #### 참고 글
# https://betterprogramming.pub/loading-location-history-places-from-google-timeline-into-pandas-and-csv-c26cb0ac5e89

# %% [markdown]
# #### 1. 구글 Location History 데이터 다운로드
# - 구글 크롬 브라우저에 로그인 된 상태에서
# - https://takeout.google.com/settings/takeout 사이트로 이동하기
# - 모두 체크를 해제시키고 **[위치 기록]** 만 체크표시하고
# - takeout-20220803T011231Z-001.zip 파일이 다운로드 된다.

# %% [markdown]
# #### 2. 필요한 라이브러리 설치하기
# 설치시 오류가 발생하면 윈도우 명령프롬프트창에서 timezonefinder 설치를 진행해 본다.

# %%
import numpy as np

np.__version__
# Out:
# '1.19.5'

# %%
# !pip install timezonefinder
# Out:
# Requirement already satisfied: timezonefinder in c:\python\python39\lib\site-packages (6.0.1)
# Collecting numpy>=1.20.3
#   Downloading numpy-1.23.3-cp39-cp39-win_amd64.whl (14.7 MB)
#      --------------------------------------- 14.7/14.7 MB 11.9 MB/s eta 0:00:00
# Requirement already satisfied: h3>=3.7.3 in c:\python\python39\lib\site-packages (from timezonefinder) (3.7.4)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\python\python39\lib\site-packages)
#     WARNING: Ignoring invalid distribution -pencv-python-headless (c:\python\python39\lib\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 5] 액세스가 거부되었습니다: 'C:\\python\\Python39\\Lib\\site-packages\\~%mpy\\.libs\\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll'
# Consider using the `--user` option or check the permissions.
#
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\python\python39\lib\site-packages)
#
# [notice] A new release of pip available: 22.2.1 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# 경도, 위도값으로 시간대 정보 가져오기
from timezonefinder import TimezoneFinder

tzf= TimezoneFinder()
tz = tzf.timezone_at(lng=128, lat=38)  # 'Asia/Seoul'
#tz = tzf.timezone_at(lng=13.358, lat=52.5061)  # 'Europe/Berlin'
tz
# Out:
# 'Asia/Seoul'

# %% [markdown]
# #### 3.나의 Local History데이터 정보를 딕셔너리타입으로 변환하기

# %%
from zipfile import ZipFile
import pandas as pd
import json
from timezonefinder import TimezoneFinder

# %%
# path to Google Location History takeout file
history_data_file = "data/takeout-20220803T011231Z-001.zip"

# store all places into this array
place_visits = []

with ZipFile(history_data_file) as myzip:
    for file in myzip.filelist[:]:
        filename = file.filename
        
        if "Semantic Location History" in filename:
            # process all files in "Semantic Location History" directory
            history_json = json.load(myzip.open(filename))

            for timeline_object in history_json["timelineObjects"]:
               
                if "placeVisit" in timeline_object:
                    place_visit_json = timeline_object["placeVisit"]
                    
                    # skip places without geographical coordinates
                    if not "location" in place_visit_json or not "latitudeE7" in place_visit_json["location"]:
                        continue
                    
                    place_visit = {
                        "placeId": place_visit_json["location"]["placeId"],
                        "locationConfidence": place_visit_json["location"]["locationConfidence"],
                        "startTimestamp": place_visit_json["duration"]["startTimestamp"],
                        "endTimestamp": place_visit_json["duration"]["endTimestamp"],
                        "placeVisitImportance": place_visit_json["placeVisitImportance"],
                        "placeVisitType": place_visit_json["placeVisitType"],
                        "latitudeE7": place_visit_json["location"]["latitudeE7"],
                        "longitudeE7": place_visit_json["location"]["longitudeE7"],
                    }
                    
                    for optional_field in ["centerLatE7", "centerLngE7"]:
                        if optional_field in place_visit_json:
                            place_visit[optional_field] = place_visit_json[optional_field]
                        else:
                            place_visit[optional_field] = None
                    
                    for optional_field in ["name", "address"]:
                        if optional_field in place_visit_json["location"]:
                            place_visit[optional_field] = place_visit_json["location"][optional_field]
                        else:
                            place_visit[optional_field] = None
                        
                    
                    place_visits.append(place_visit)

place_visits
# Out:
# [{'placeId': 'ChIJ-TPmtZ5hezUR_ynve8y3RN8',
#   'locationConfidence': 94.88838,
#   'startTimestamp': '2022-08-01T07:58:34.215Z',
#   'endTimestamp': '2022-08-01T08:44:38.168Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374472973,
#   'longitudeE7': 1268854894,
#   'centerLatE7': 374479545,
#   'centerLngE7': 1268851510,
#   'name': '개성손만두',
#   'address': '대한민국 광명시 소하동 1337번지 103호 광명시 경기도 KR'},
#  {'placeId': 'ChIJiWKXIGxhezURSdDzm8-jpb0',
#   'locationConfidence': 71.79532,
#   'startTimestamp': '2022-08-01T09:21:21.989Z',
#   'endTimestamp': '2022-08-02T08:39:53.052Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374308554,
#   'longitudeE7': 1268842593,
#   'centerLatE7': 374308490,
#   'centerLngE7': 1268843140,
#   'name': '501 광명역세권휴먼시아5단지',
#   'address': '대한민국 광명시 소하2동'},
#  {'placeId': 'ChIJkT4EGUFhezURmFNNjUBhZdw',
#   'locationConfidence': 91.55132,
#   'startTimestamp': '2022-08-02T08:54:19.849Z',
#   'endTimestamp': '2022-08-02T09:47:05.617Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374208559,
#   'longitudeE7': 1268858135,
#   'centerLatE7': 374208989,
#   'centerLngE7': 1268855516,
#   'name': 'Costco Wholesale Gwangmyeong',
#   'address': '대한민국 경기도 광명시 일직로 40'},
#  {'placeId': 'ChIJiWKXIGxhezURSdDzm8-jpb0',
#   'locationConfidence': 70.12085,
#   'startTimestamp': '2022-08-02T10:03:04.965Z',
#   'endTimestamp': '2022-08-02T18:20:28.867Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374308554,
#   'longitudeE7': 1268842593,
#   'centerLatE7': 374308259,
#   'centerLngE7': 1268842914,
#   'name': '501 광명역세권휴먼시아5단지',
#   'address': '대한민국 광명시 소하2동'},
#  {'placeId': 'ChIJl4xz5DalfDUR5J-cZDd1bDM',
#   'locationConfidence': 87.75959,
#   'startTimestamp': '2022-07-02T02:07:57.776Z',
#   'endTimestamp': '2022-07-02T08:29:09.583Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 375116828,
#   'longitudeE7': 1270591510,
#   'centerLatE7': 375114638,
#   'centerLngE7': 1270595248,
#   'name': 'COEX',
#   'address': '대한민국 서울특별시 강남구 영동대로 513'},
#  {'placeId': 'ChIJzZ07yMqlfDURfXWGeD8mnec',
#   'locationConfidence': 87.74342,
#   'startTimestamp': '2022-07-02T08:32:46.175Z',
#   'endTimestamp': '2022-07-02T11:04:52.454Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 375086154,
#   'longitudeE7': 1270597808,
#   'centerLatE7': 375085609,
#   'centerLngE7': 1270597290,
#   'name': 'Hyundai Department Store Trade Center',
#   'address': '대한민국 서울특별시 강남구 삼성동 테헤란로 517'},
#  {'placeId': 'ChIJl4xz5DalfDUR5J-cZDd1bDM',
#   'locationConfidence': 22.308754,
#   'startTimestamp': '2022-07-02T11:26:17.503Z',
#   'endTimestamp': '2022-07-03T00:50:40.411Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 375116828,
#   'longitudeE7': 1270591510,
#   'centerLatE7': 375128502,
#   'centerLngE7': 1270572047,
#   'name': 'COEX',
#   'address': '대한민국 서울특별시 강남구 영동대로 513'},
#  {'placeId': 'ChIJgZn6QWmkfDURaU3kwlecaEU',
#   'locationConfidence': 95.73945,
#   'startTimestamp': '2022-07-03T00:54:23.868Z',
#   'endTimestamp': '2022-07-03T01:21:32.706Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 375148520,
#   'longitudeE7': 1270573766,
#   'centerLatE7': 375149395,
#   'centerLngE7': 1270575550,
#   'name': 'Bongeunsa',
#   'address': '대한민국 서울특별시 강남구 봉은사로 531'},
#  {'placeId': 'ChIJuVvOr2qkfDURVbtWdno9Rr4',
#   'locationConfidence': 29.705126,
#   'startTimestamp': '2022-07-03T01:21:32.706Z',
#   'endTimestamp': '2022-07-03T02:09:23.685Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 375126188,
#   'longitudeE7': 1270574169,
#   'centerLatE7': 375129244,
#   'centerLngE7': 1270571924,
#   'name': 'The Brasserie',
#   'address': '대한민국 서울특별시 강남구 삼성1동 봉은사로 524 인터컨티넨탈 코엑스 1층'},
#  {'placeId': 'ChIJiWKXIGxhezURSdDzm8-jpb0',
#   'locationConfidence': 73.22595,
#   'startTimestamp': '2022-07-03T02:51:36.460Z',
#   'endTimestamp': '2022-07-04T00:04:55.121Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374308554,
#   'longitudeE7': 1268842593,
#   'centerLatE7': 374308579,
#   'centerLngE7': 1268843465,
#   'name': '501 광명역세권휴먼시아5단지',
#   'address': '대한민국 광명시 소하2동'},
#  {'placeId': 'ChIJiWKXIGxhezURSdDzm8-jpb0',
#   'locationConfidence': 71.645294,
#   'startTimestamp': '2022-07-04T01:22:06Z',
#   'endTimestamp': '2022-07-05T06:29:07.579Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374308554,
#   'longitudeE7': 1268842593,
#   'centerLatE7': 374308901,
#   'centerLngE7': 1268842824,
#   'name': '501 광명역세권휴먼시아5단지',
#   'address': '대한민국 광명시 소하2동'},
#  {'placeId': 'ChIJpVT-WLBlezURI2UitKht3Ck',
#   'locationConfidence': 96.42227,
#   'startTimestamp': '2022-07-05T06:56:06.161Z',
#   'endTimestamp': '2022-07-05T07:15:21.082Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 373843602,
#   'longitudeE7': 1268309330,
#   'centerLatE7': 373842244,
#   'centerLngE7': 1268307711,
#   'name': '안산농협 연꽃 로컬푸드',
#   'address': '대한민국 경기도 시흥시 목감동 동서로 770'},
#  {'placeId': 'ChIJiWKXIGxhezURSdDzm8-jpb0',
#   'locationConfidence': 60.22075,
#   'startTimestamp': '2022-07-05T07:40:17.993Z',
#   'endTimestamp': '2022-07-05T07:53:48.525Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374308554,
#   'longitudeE7': 1268842593,
#   'centerLatE7': 374307583,
#   'centerLngE7': 1268841200,
#   'name': '501 광명역세권휴먼시아5단지',
#   'address': '대한민국 광명시 소하2동'},
#  {'placeId': 'ChIJWR9uIKJhezURRF5w8GADdsQ',
#   'locationConfidence': 57.491016,
#   'startTimestamp': '2022-07-05T08:07:03.473Z',
#   'endTimestamp': '2022-07-05T08:46:58.941Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374483607,
#   'longitudeE7': 1268862353,
#   'centerLatE7': 374473721,
#   'centerLngE7': 1268855737,
#   'name': '한내근린공원',
#   'address': '대한민국 경기도 광명시 소하1동 444-1'},
#  {'placeId': 'ChIJiWKXIGxhezURSdDzm8-jpb0',
#   'locationConfidence': 66.963165,
#   'startTimestamp': '2022-07-05T09:16:58.570Z',
#   'endTimestamp': '2022-07-06T08:55:09.784Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374308554,
#   'longitudeE7': 1268842593,
#   'centerLatE7': 374308666,
#   'centerLngE7': 1268844800,
#   'name': '501 광명역세권휴먼시아5단지',
#   'address': '대한민국 광명시 소하2동'},
#  {'placeId': 'ChIJiWKXIGxhezURSdDzm8-jpb0',
#   'locationConfidence': 67.92871,
#   'startTimestamp': '2022-07-06T09:52:06.483Z',
#   'endTimestamp': '2022-07-07T22:54:37.033Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374308554,
#   'longitudeE7': 1268842593,
#   'centerLatE7': 374308645,
#   'centerLngE7': 1268843852,
#   'name': '501 광명역세권휴먼시아5단지',
#   'address': '대한민국 광명시 소하2동'},
#  {'placeId': 'ChIJAzuRyrzZejURHozP5khap7w',
#   'locationConfidence': 88.58187,
#   'startTimestamp': '2022-07-08T00:12:19.718Z',
#   'endTimestamp': '2022-07-08T08:17:45Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 367899199,
#   'longitudeE7': 1271072194,
#   'centerLatE7': 367897876,
#   'centerLngE7': 1271074163,
#   'name': '충남콘텐츠기업육성센터',
#   'address': '대한민국 충청남도 아산시 배방읍 희망로46번길 45-11'},
#  {'placeId': 'ChIJiWKXIGxhezURSdDzm8-jpb0',
#   'locationConfidence': 66.99286,
#   'startTimestamp': '2022-07-08T10:17:54.987Z',
#   'endTimestamp': '2022-07-09T01:43:20.232Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374308554,
#   'longitudeE7': 1268842593,
#   'centerLatE7': 374308855,
#   'centerLngE7': 1268843332,
#   'name': '501 광명역세권휴먼시아5단지',
#   'address': '대한민국 광명시 소하2동'},
#  {'placeId': 'ChIJZdmUE1FhezURAbvJrynG6ZY',
#   'locationConfidence': 43.710144,
#   'startTimestamp': '2022-07-09T01:58:00.497Z',
#   'endTimestamp': '2022-07-09T02:28:54.504Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374199623,
#   'longitudeE7': 1268895002,
#   'centerLatE7': 374198515,
#   'centerLngE7': 1268894669,
#   'name': '(주)광명무역센터컨벤션',
#   'address': '대한민국 경기도 광명시 일직동 일직로 72'},
#  {'placeId': 'ChIJkT4EGUFhezURmFNNjUBhZdw',
#   'locationConfidence': 90.27845,
#   'startTimestamp': '2022-07-09T02:32:23.491Z',
#   'endTimestamp': '2022-07-09T02:38:24.613Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374206838,
#   'longitudeE7': 1268864277,
#   'centerLatE7': 374211933,
#   'centerLngE7': 1268860500,
#   'name': 'Costco Wholesale - Gwangmyeong Branch',
#   'address': '대한민국 경기도 광명시 일직로 40'},
#  {'placeId': 'ChIJif2a9EFhezURHkD8egX3ht0',
#   'locationConfidence': 83.83199,
#   'startTimestamp': '2022-07-09T02:44:53.244Z',
#   'endTimestamp': '2022-07-09T03:37:16.448Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374245517,
#   'longitudeE7': 1268842226,
#   'centerLatE7': 374236356,
#   'centerLngE7': 1268847159,
#   'name': 'LOTTE Mall Gwangmyeong',
#   'address': '대한민국 경기도 광명시 일직로 17'},
#  {'placeId': 'ChIJiWKXIGxhezURSdDzm8-jpb0',
#   'locationConfidence': 69.00667,
#   'startTimestamp': '2022-07-09T03:46:48.452Z',
#   'endTimestamp': '2022-07-12T05:49:19.609Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374308554,
#   'longitudeE7': 1268842593,
#   'centerLatE7': 374307357,
#   'centerLngE7': 1268845172,
#   'name': '501 광명역세권휴먼시아5단지',
#   'address': '대한민국 광명시 소하2동'},
#  {'placeId': 'ChIJkT4EGUFhezURmFNNjUBhZdw',
#   'locationConfidence': 92.766136,
#   'startTimestamp': '2022-07-12T05:56:28.658Z',
#   'endTimestamp': '2022-07-12T07:27:20.359Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374206838,
#   'longitudeE7': 1268864277,
#   'centerLatE7': 374206895,
#   'centerLngE7': 1268857892,
#   'name': 'Costco Wholesale - Gwangmyeong Branch',
#   'address': '대한민국 경기도 광명시 일직로 40'},
#  {'placeId': 'ChIJiWKXIGxhezURSdDzm8-jpb0',
#   'locationConfidence': 75.395,
#   'startTimestamp': '2022-07-12T07:37:57.428Z',
#   'endTimestamp': '2022-07-14T04:08:39.268Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374308554,
#   'longitudeE7': 1268842593,
#   'centerLatE7': 374308898,
#   'centerLngE7': 1268843253,
#   'name': '501 광명역세권휴먼시아5단지',
#   'address': '대한민국 광명시 소하2동'},
#  {'placeId': 'ChIJif2a9EFhezURHkD8egX3ht0',
#   'locationConfidence': 78.04197,
#   'startTimestamp': '2022-07-14T04:21:29.735Z',
#   'endTimestamp': '2022-07-14T04:38:47.751Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374245517,
#   'longitudeE7': 1268842226,
#   'centerLatE7': 374236615,
#   'centerLngE7': 1268847277,
#   'name': 'LOTTE Mall Gwangmyeong',
#   'address': '대한민국 경기도 광명시 일직로 17'},
#  {'placeId': 'ChIJiWKXIGxhezURSdDzm8-jpb0',
#   'locationConfidence': 83.915764,
#   'startTimestamp': '2022-07-14T04:49:59.053Z',
#   'endTimestamp': '2022-07-14T09:14:17.473Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374308554,
#   'longitudeE7': 1268842593,
#   'centerLatE7': 374308168,
#   'centerLngE7': 1268844365,
#   'name': '501 광명역세권휴먼시아5단지',
#   'address': '대한민국 광명시 소하2동'},
#  {'placeId': 'ChIJiWKXIGxhezURSdDzm8-jpb0',
#   'locationConfidence': 62.59535,
#   'startTimestamp': '2022-07-14T10:00:53.312Z',
#   'endTimestamp': '2022-07-16T00:51:30.189Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374308554,
#   'longitudeE7': 1268842593,
#   'centerLatE7': 374308615,
#   'centerLngE7': 1268842359,
#   'name': '501 광명역세권휴먼시아5단지',
#   'address': '대한민국 광명시 소하2동'},
#  {'placeId': 'ChIJoYohZ0VhezURv8JUckZvuno',
#   'locationConfidence': 95.717255,
#   'startTimestamp': '2022-07-16T01:12:39.489Z',
#   'endTimestamp': '2022-07-16T02:49:26.125Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374186118,
#   'longitudeE7': 1268829051,
#   'centerLatE7': 374193957,
#   'centerLngE7': 1268831590,
#   'name': 'Take Hotel',
#   'address': '대한민국 경기도 광명시 신기로 22'},
#  {'placeId': 'ChIJiWKXIGxhezURSdDzm8-jpb0',
#   'locationConfidence': 62.777172,
#   'startTimestamp': '2022-07-16T03:05:49.325Z',
#   'endTimestamp': '2022-07-16T03:44:08.686Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374308554,
#   'longitudeE7': 1268842593,
#   'centerLatE7': 374307320,
#   'centerLngE7': 1268845385,
#   'name': '501 광명역세권휴먼시아5단지',
#   'address': '대한민국 광명시 소하2동'},
#  {'placeId': 'ChIJCYvsb-1hezURY9Rfvju_b7c',
#   'locationConfidence': 48.906456,
#   'startTimestamp': '2022-07-16T04:06:27.437Z',
#   'endTimestamp': '2022-07-16T06:12:38.468Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374654898,
#   'longitudeE7': 1268793431,
#   'centerLatE7': 374663669,
#   'centerLngE7': 1268791976,
#   'name': '하안주공10단지',
#   'address': '대한민국 경기도 광명시 하안로 320'},
#  {'placeId': 'ChIJiWKXIGxhezURSdDzm8-jpb0',
#   'locationConfidence': 67.36823,
#   'startTimestamp': '2022-07-16T06:36:53.442Z',
#   'endTimestamp': '2022-07-17T03:33:25.072Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374308554,
#   'longitudeE7': 1268842593,
#   'centerLatE7': 374307822,
#   'centerLngE7': 1268843575,
#   'name': '501 광명역세권휴먼시아5단지',
#   'address': '대한민국 광명시 소하2동'},
#  {'placeId': 'ChIJif2a9EFhezURHkD8egX3ht0',
#   'locationConfidence': 94.55464,
#   'startTimestamp': '2022-07-17T03:42:54.751Z',
#   'endTimestamp': '2022-07-17T05:20:27.971Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374245517,
#   'longitudeE7': 1268842226,
#   'centerLatE7': 374237139,
#   'centerLngE7': 1268847133,
#   'name': 'LOTTE Mall Gwangmyeong',
#   'address': '대한민국 경기도 광명시 일직로 17'},
#  {'placeId': 'ChIJiWKXIGxhezURSdDzm8-jpb0',
#   'locationConfidence': 69.52066,
#   'startTimestamp': '2022-07-17T05:32:57.393Z',
#   'endTimestamp': '2022-07-17T09:18:34.412Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374308554,
#   'longitudeE7': 1268842593,
#   'centerLatE7': 374307222,
#   'centerLngE7': 1268845688,
#   'name': '501 광명역세권휴먼시아5단지',
#   'address': '대한민국 광명시 소하2동'},
#  {'placeId': 'ChIJif2a9EFhezURHkD8egX3ht0',
#   'locationConfidence': 91.71461,
#   'startTimestamp': '2022-07-17T09:29:14.213Z',
#   'endTimestamp': '2022-07-17T11:06:27.662Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374245517,
#   'longitudeE7': 1268842226,
#   'centerLatE7': 374236153,
#   'centerLngE7': 1268847622,
#   'name': 'LOTTE Mall Gwangmyeong',
#   'address': '대한민국 경기도 광명시 일직로 17'},
#  {'placeId': 'ChIJiWKXIGxhezURSdDzm8-jpb0',
#   'locationConfidence': 68.87489,
#   'startTimestamp': '2022-07-17T11:19:59.572Z',
#   'endTimestamp': '2022-07-18T00:25:17.406Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374308554,
#   'longitudeE7': 1268842593,
#   'centerLatE7': 374306999,
#   'centerLngE7': 1268845789,
#   'name': '501 광명역세권휴먼시아5단지',
#   'address': '대한민국 광명시 소하2동'},
#  {'placeId': 'ChIJc6CYkW9hezURboWsViBN7_k',
#   'locationConfidence': 85.87011,
#   'startTimestamp': '2022-07-18T01:51:12.999Z',
#   'endTimestamp': '2022-07-18T02:01:44Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374321062,
#   'longitudeE7': 1268797329,
#   'centerLatE7': 374319854,
#   'centerLngE7': 1268803231,
#   'name': '소하동우체국',
#   'address': '대한민국 경기도 광명시 소하동 1067-2'},
#  {'placeId': 'ChIJiWKXIGxhezURSdDzm8-jpb0',
#   'locationConfidence': 70.24096,
#   'startTimestamp': '2022-07-18T02:05:39Z',
#   'endTimestamp': '2022-07-19T02:23:58.907Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374308554,
#   'longitudeE7': 1268842593,
#   'centerLatE7': 374308977,
#   'centerLngE7': 1268843892,
#   'name': '501 광명역세권휴먼시아5단지',
#   'address': '대한민국 광명시 소하2동'},
#  {'placeId': 'ChIJC6wM8BJhezUR9i1VmLeA-54',
#   'locationConfidence': 44.761337,
#   'startTimestamp': '2022-07-19T02:32:32.348Z',
#   'endTimestamp': '2022-07-19T05:53:54.392Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374195927,
#   'longitudeE7': 1268885500,
#   'centerLatE7': 374195004,
#   'centerLngE7': 1268882698,
#   'name': 'Chohyang-Gag',
#   'address': '대한민국 경기도 광명시 새빛공원로 67'},
#  {'placeId': 'ChIJif2a9EFhezURHkD8egX3ht0',
#   'locationConfidence': 93.9614,
#   'startTimestamp': '2022-07-19T05:59:53.846Z',
#   'endTimestamp': '2022-07-19T06:12:22.592Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374245517,
#   'longitudeE7': 1268842226,
#   'centerLatE7': 374240500,
#   'centerLngE7': 1268845100,
#   'name': 'LOTTE Mall Gwangmyeong',
#   'address': '대한민국 경기도 광명시 일직로 17'},
#  {'placeId': 'ChIJiWKXIGxhezURSdDzm8-jpb0',
#   'locationConfidence': 77.400604,
#   'startTimestamp': '2022-07-19T06:18:48.548Z',
#   'endTimestamp': '2022-07-20T03:02:39.420Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374308554,
#   'longitudeE7': 1268842593,
#   'centerLatE7': 374308156,
#   'centerLngE7': 1268843461,
#   'name': '501 광명역세권휴먼시아5단지',
#   'address': '대한민국 광명시 소하2동'},
#  {'placeId': 'ChIJF6qs-dCcfDURVMw5Ij-Qd6w',
#   'locationConfidence': 94.65937,
#   'startTimestamp': '2022-07-20T03:45:54.204Z',
#   'endTimestamp': '2022-07-20T05:26:28.702Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 375586545,
#   'longitudeE7': 1267944739,
#   'centerLatE7': 375589818,
#   'centerLngE7': 1268027198,
#   'name': 'Gimpo International Airport',
#   'address': '대한민국 서울특별시 강서구 하늘길 112'},
#  {'placeId': 'ChIJxb_FCjv7DDURZ8wL9kMz_-0',
#   'locationConfidence': 93.0882,
#   'startTimestamp': '2022-07-20T06:46:51.920Z',
#   'endTimestamp': '2022-07-20T06:56:59.143Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 335104135,
#   'longitudeE7': 1264913534,
#   'centerLatE7': 335062192,
#   'centerLngE7': 1264932000,
#   'name': 'Jeju International Airport',
#   'address': '대한민국 제주특별자치도 제주시 공항로 2'},
#  {'placeId': 'ChIJqYdMhQn7DDURCahwRRWdO0A',
#   'locationConfidence': 85.28057,
#   'startTimestamp': '2022-07-20T07:03:05.682Z',
#   'endTimestamp': '2022-07-20T07:31:16.020Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 334823570,
#   'longitudeE7': 1264948340,
#   'centerLatE7': 334819881,
#   'centerLngE7': 1264947706,
#   'name': 'Benikea I-Jin Hotel',
#   'address': '대한민국 제주특별자치도 제주시 특별자치도, 연동 306-14 KR'},
#  {'placeId': 'ChIJKcE56O76DDURWd-bvIAK_So',
#   'locationConfidence': 99.31721,
#   'startTimestamp': '2022-07-20T08:02:39.603Z',
#   'endTimestamp': '2022-07-20T09:15:43.476Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 335038914,
#   'longitudeE7': 1264653931,
#   'centerLatE7': 335039041,
#   'centerLngE7': 1264653718,
#   'name': '삼성혈해물탕 도두점',
#   'address': '대한민국 제주특별자치도 제주시 도두일동 도두항서7길 23'},
#  {'placeId': 'ChIJqYdMhQn7DDURCahwRRWdO0A',
#   'locationConfidence': 77.35371,
#   'startTimestamp': '2022-07-20T10:08:10.138Z',
#   'endTimestamp': '2022-07-20T22:57:02.999Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 334823570,
#   'longitudeE7': 1264948340,
#   'centerLatE7': 334819857,
#   'centerLngE7': 1264946589,
#   'name': 'Benikea I-Jin Hotel',
#   'address': '대한민국 제주특별자치도 제주시 특별자치도, 연동 306-14 KR'},
#  {'placeId': 'ChIJrf30EAv9DDURgISUGEN0aM4',
#   'locationConfidence': 52.213062,
#   'startTimestamp': '2022-07-20T23:14:25.303Z',
#   'endTimestamp': '2022-07-21T09:15:02.383Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 334469580,
#   'longitudeE7': 1265678683,
#   'centerLatE7': 334473033,
#   'centerLngE7': 1265678307,
#   'name': '제주산학융합원',
#   'address': '대한민국 제주특별자치도 제주시 특별자치도 첨단로8길 40'},
#  {'placeId': 'ChIJ41wytQn7DDUR7gLAPQVUqNI',
#   'locationConfidence': 89.45284,
#   'startTimestamp': '2022-07-21T09:44:34.507Z',
#   'endTimestamp': '2022-07-21T10:29:35.666Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 334824446,
#   'longitudeE7': 1264932441,
#   'centerLatE7': 334823088,
#   'centerLngE7': 1264931162,
#   'name': 'Soliwon',
#   'address': '대한민국 제주특별자치도 제주시 연동'},
#  {'placeId': 'ChIJqYdMhQn7DDURCahwRRWdO0A',
#   'locationConfidence': 90.98197,
#   'startTimestamp': '2022-07-21T10:33:12.524Z',
#   'endTimestamp': '2022-07-21T23:00:03.874Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 334823570,
#   'longitudeE7': 1264948340,
#   'centerLatE7': 334818714,
#   'centerLngE7': 1264946632,
#   'name': 'Benikea I-Jin Hotel',
#   'address': '대한민국 제주특별자치도 제주시 특별자치도, 연동 306-14 KR'},
#  {'placeId': 'ChIJrf30EAv9DDURgISUGEN0aM4',
#   'locationConfidence': 52.72897,
#   'startTimestamp': '2022-07-21T23:16:46.903Z',
#   'endTimestamp': '2022-07-22T09:07:12.010Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 334469580,
#   'longitudeE7': 1265678683,
#   'centerLatE7': 334472885,
#   'centerLngE7': 1265678315,
#   'name': '제주산학융합원',
#   'address': '대한민국 제주특별자치도 제주시 특별자치도 첨단로8길 40'},
#  {'placeId': 'ChIJqYdMhQn7DDURCahwRRWdO0A',
#   'locationConfidence': 80.04844,
#   'startTimestamp': '2022-07-22T09:47:30.443Z',
#   'endTimestamp': '2022-07-22T10:05:39Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 334823570,
#   'longitudeE7': 1264948340,
#   'centerLatE7': 334821279,
#   'centerLngE7': 1264948314,
#   'name': 'Benikea I-Jin Hotel',
#   'address': '대한민국 제주특별자치도 제주시 특별자치도, 연동 306-14 KR'},
#  {'placeId': 'ChIJwW7IEAr7DDURaPGQLJiXNOk',
#   'locationConfidence': 97.51075,
#   'startTimestamp': '2022-07-22T10:05:39Z',
#   'endTimestamp': '2022-07-22T10:48:16.134Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 334807098,
#   'longitudeE7': 1264966744,
#   'centerLatE7': 334809113,
#   'centerLngE7': 1264966507,
#   'name': '서울뚝배기 2호점',
#   'address': '대한민국 제주특별자치도 제주시 연동 528-4'},
#  {'placeId': 'ChIJqYdMhQn7DDURCahwRRWdO0A',
#   'locationConfidence': 93.8897,
#   'startTimestamp': '2022-07-22T10:50:13.521Z',
#   'endTimestamp': '2022-07-22T23:09:51.290Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 334823570,
#   'longitudeE7': 1264948340,
#   'centerLatE7': 334819250,
#   'centerLngE7': 1264946333,
#   'name': 'Benikea I-Jin Hotel',
#   'address': '대한민국 제주특별자치도 제주시 특별자치도, 연동 306-14 KR'},
#  {'placeId': 'ChIJrf30EAv9DDURgISUGEN0aM4',
#   'locationConfidence': 51.17588,
#   'startTimestamp': '2022-07-22T23:26:11.361Z',
#   'endTimestamp': '2022-07-23T09:09:18.747Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 334469580,
#   'longitudeE7': 1265678683,
#   'centerLatE7': 334472881,
#   'centerLngE7': 1265678326,
#   'name': '제주산학융합원',
#   'address': '대한민국 제주특별자치도 제주시 특별자치도 첨단로8길 40'},
#  {'placeId': 'ChIJa_Q7KlP6DDUR3tX842TX7Ts',
#   'locationConfidence': 97.324524,
#   'startTimestamp': '2022-07-23T09:27:03.676Z',
#   'endTimestamp': '2022-07-23T10:57:24.722Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 334786435,
#   'longitudeE7': 1264794336,
#   'centerLatE7': 334786602,
#   'centerLngE7': 1264794361,
#   'name': 'Okinawa',
#   'address': '대한민국 제주특별자치도 제주시 노형동 747-1'},
#  {'placeId': 'ChIJqYdMhQn7DDURCahwRRWdO0A',
#   'locationConfidence': 96.48123,
#   'startTimestamp': '2022-07-23T11:22:53.289Z',
#   'endTimestamp': '2022-07-24T00:11:00.853Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 334823570,
#   'longitudeE7': 1264948340,
#   'centerLatE7': 334820095,
#   'centerLngE7': 1264946932,
#   'name': 'Benikea I-Jin Hotel',
#   'address': '대한민국 제주특별자치도 제주시 특별자치도, 연동 306-14 KR'},
#  {'placeId': 'ChIJX7tjOgj7DDURA1mx_fboS08',
#   'locationConfidence': 84.109726,
#   'startTimestamp': '2022-07-24T00:15:08.132Z',
#   'endTimestamp': '2022-07-24T01:42:16.891Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 334821540,
#   'longitudeE7': 1264924803,
#   'centerLatE7': 334819481,
#   'centerLngE7': 1264925435,
#   'name': '아일랜드마이빌',
#   'address': '대한민국 제주특별자치도 제주시 연동 1373-1'},
#  {'placeId': 'ChIJqYdMhQn7DDURCahwRRWdO0A',
#   'locationConfidence': 75.33166,
#   'startTimestamp': '2022-07-24T01:45:22.981Z',
#   'endTimestamp': '2022-07-24T02:23:39.881Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 334823570,
#   'longitudeE7': 1264948340,
#   'centerLatE7': 334817449,
#   'centerLngE7': 1264946829,
#   'name': 'Benikea I-Jin Hotel',
#   'address': '대한민국 제주특별자치도 제주시 특별자치도, 연동 306-14 KR'},
#  {'placeId': 'ChIJX8NcsJT8DDURgb49g3wvd5c',
#   'locationConfidence': 91.97565,
#   'startTimestamp': '2022-07-24T02:45:16.051Z',
#   'endTimestamp': '2022-07-24T02:51:16.070Z',
#   'placeVisitImportance': 'TRANSITIONAL',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 334794730,
#   'longitudeE7': 1265439310,
#   'centerLatE7': 334796940,
#   'centerLngE7': 1265437540,
#   'name': 'Namgug-Won',
#   'address': '대한민국 제주시'},
#  {'placeId': 'ChIJBRZpImkCDTURh-DUBUdxEl8',
#   'locationConfidence': 97.22314,
#   'startTimestamp': '2022-07-24T03:16:16.206Z',
#   'endTimestamp': '2022-07-24T03:25:47.999Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 334230049,
#   'longitudeE7': 1266268677,
#   'centerLatE7': 334222042,
#   'centerLngE7': 1266263450,
#   'name': 'Saryeoni Forest Path',
#   'address': '대한민국 제주특별자치도 제주시 조천읍 교래리 산 137-1'},
#  {'placeId': 'ChIJBRZpImkCDTURh-DUBUdxEl8',
#   'locationConfidence': 95.840355,
#   'startTimestamp': '2022-07-24T05:06:48Z',
#   'endTimestamp': '2022-07-24T05:26:29.999Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 334230049,
#   'longitudeE7': 1266268677,
#   'centerLatE7': 334228012,
#   'centerLngE7': 1266263965,
#   'name': 'Saryeoni Forest Path',
#   'address': '대한민국 제주특별자치도 제주시 조천읍 교래리 산 137-1'},
#  {'placeId': 'ChIJ4apxS6_8DDURNArV40vCwhc',
#   'locationConfidence': 94.55388,
#   'startTimestamp': '2022-07-24T06:03:29.746Z',
#   'endTimestamp': '2022-07-24T08:04:28.999Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 334985741,
#   'longitudeE7': 1265287253,
#   'centerLatE7': 334986176,
#   'centerLngE7': 1265287204,
#   'name': 'Coffee Finder',
#   'address': '대한민국 제주특별자치도 제주시 이도이동 서광로32길 20'},
#  {'placeId': 'ChIJ4dL0M1fjDDURpXxXvaqxt_g',
#   'locationConfidence': 99.5028,
#   'startTimestamp': '2022-07-24T08:15:14.702Z',
#   'endTimestamp': '2022-07-24T09:31:25.824Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 335163432,
#   'longitudeE7': 1265281752,
#   'centerLatE7': 335163504,
#   'centerLngE7': 1265280110,
#   'name': 'Gozip Dol Wooluck',
#   'address': '대한민국 제주시 KR특별자치도 제주시 건입동 임항로 30'},
#  {'placeId': 'ChIJqYdMhQn7DDURCahwRRWdO0A',
#   'locationConfidence': 86.85858,
#   'startTimestamp': '2022-07-24T10:12:41.024Z',
#   'endTimestamp': '2022-07-24T23:05:23.629Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 334823570,
#   'longitudeE7': 1264948340,
#   'centerLatE7': 334819514,
#   'centerLngE7': 1264946749,
#   'name': 'Benikea I-Jin Hotel',
#   'address': '대한민국 제주특별자치도 제주시 특별자치도, 연동 306-14 KR'},
#  {'placeId': 'ChIJrf30EAv9DDURgISUGEN0aM4',
#   'locationConfidence': 58.46531,
#   'startTimestamp': '2022-07-24T23:24:10.874Z',
#   'endTimestamp': '2022-07-25T09:09:00.262Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 334469580,
#   'longitudeE7': 1265678683,
#   'centerLatE7': 334472984,
#   'centerLngE7': 1265678504,
#   'name': '제주산학융합원',
#   'address': '대한민국 제주특별자치도 제주시 특별자치도 첨단로8길 40'},
#  {'placeId': 'ChIJtV0qWgn7DDURJIIjMkVCVvc',
#   'locationConfidence': 98.87159,
#   'startTimestamp': '2022-07-25T09:42:19.038Z',
#   'endTimestamp': '2022-07-25T10:29:03.779Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 334844023,
#   'longitudeE7': 1264955507,
#   'centerLatE7': 334842806,
#   'centerLngE7': 1264956181,
#   'name': '황금어장',
#   'address': '대한민국 제주특별자치도 제주시 연동 사장길 14'},
#  {'placeId': 'ChIJqYdMhQn7DDURCahwRRWdO0A',
#   'locationConfidence': 95.589134,
#   'startTimestamp': '2022-07-25T10:32:00.088Z',
#   'endTimestamp': '2022-07-25T23:07:52.653Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 334823570,
#   'longitudeE7': 1264948340,
#   'centerLatE7': 334819830,
#   'centerLngE7': 1264946648,
#   'name': 'Benikea I-Jin Hotel',
#   'address': '대한민국 제주특별자치도 제주시 특별자치도, 연동 306-14 KR'},
#  {'placeId': 'ChIJrf30EAv9DDURgISUGEN0aM4',
#   'locationConfidence': 60.769073,
#   'startTimestamp': '2022-07-25T23:27:40.261Z',
#   'endTimestamp': '2022-07-26T09:08:02.982Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 334469580,
#   'longitudeE7': 1265678683,
#   'centerLatE7': 334473250,
#   'centerLngE7': 1265678959,
#   'name': '제주산학융합원',
#   'address': '대한민국 제주특별자치도 제주시 특별자치도 첨단로8길 40'},
#  {'placeId': 'ChIJxb_FCjv7DDURZ8wL9kMz_-0',
#   'locationConfidence': 96.758835,
#   'startTimestamp': '2022-07-26T09:47:48.430Z',
#   'endTimestamp': '2022-07-26T11:23:55.295Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 335104135,
#   'longitudeE7': 1264913534,
#   'centerLatE7': 335070604,
#   'centerLngE7': 1264927079,
#   'name': 'Jeju International Airport',
#   'address': '대한민국 제주특별자치도 제주시 공항로 2'},
#  {'placeId': 'ChIJF6qs-dCcfDURVMw5Ij-Qd6w',
#   'locationConfidence': 93.384636,
#   'startTimestamp': '2022-07-26T12:34:50.510Z',
#   'endTimestamp': '2022-07-26T12:43:22.351Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 375586545,
#   'longitudeE7': 1267944739,
#   'centerLatE7': 375592800,
#   'centerLngE7': 1268032778,
#   'name': 'Gimpo International Airport',
#   'address': '대한민국 서울특별시 강서구 하늘길 112'},
#  {'placeId': 'ChIJiWKXIGxhezURSdDzm8-jpb0',
#   'locationConfidence': 68.06271,
#   'startTimestamp': '2022-07-26T13:18:04.013Z',
#   'endTimestamp': '2022-07-28T09:28:09Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374308554,
#   'longitudeE7': 1268842593,
#   'centerLatE7': 374308707,
#   'centerLngE7': 1268842019,
#   'name': '501 광명역세권휴먼시아5단지',
#   'address': '대한민국 광명시 소하2동'},
#  {'placeId': 'ChIJ_6chamhhezURQfOZsReDjBU',
#   'locationConfidence': 45.801273,
#   'startTimestamp': '2022-07-28T09:31:50.585Z',
#   'endTimestamp': '2022-07-28T10:07:40.872Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374325969,
#   'longitudeE7': 1268798556,
#   'centerLatE7': 374326333,
#   'centerLngE7': 1268801596,
#   'name': '국수나무 광명충현점',
#   'address': '대한민국 경기도 광명시 성채로 50번길 9-11 101호'},
#  {'placeId': 'ChIJiWKXIGxhezURSdDzm8-jpb0',
#   'locationConfidence': 74.1788,
#   'startTimestamp': '2022-07-28T10:19:44.507Z',
#   'endTimestamp': '2022-07-29T07:25:05.116Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374308554,
#   'longitudeE7': 1268842593,
#   'centerLatE7': 374308586,
#   'centerLngE7': 1268842125,
#   'name': '501 광명역세권휴먼시아5단지',
#   'address': '대한민국 광명시 소하2동'},
#  {'placeId': 'ChIJIwCT4-yifDUR1E63iG76hr0',
#   'locationConfidence': 68.11153,
#   'startTimestamp': '2022-07-29T08:33:45.999Z',
#   'endTimestamp': '2022-07-29T10:39:59.523Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 375691015,
#   'longitudeE7': 1269786692,
#   'centerLatE7': 375691656,
#   'centerLngE7': 1269789941,
#   'name': 'Cheonggyecheon',
#   'address': '대한민국 서울특별시 종로구 청계천로 1'},
#  {'placeId': 'ChIJiWKXIGxhezURSdDzm8-jpb0',
#   'locationConfidence': 67.56665,
#   'startTimestamp': '2022-07-29T11:54:52.347Z',
#   'endTimestamp': '2022-07-31T01:01:36.805Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374308554,
#   'longitudeE7': 1268842593,
#   'centerLatE7': 374308005,
#   'centerLngE7': 1268842585,
#   'name': '501 광명역세권휴먼시아5단지',
#   'address': '대한민국 광명시 소하2동'},
#  {'placeId': 'ChIJVwJW829hezURambBObg3Tn4',
#   'locationConfidence': 98.35833,
#   'startTimestamp': '2022-07-31T01:11:37.890Z',
#   'endTimestamp': '2022-07-31T02:20:12.381Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374348248,
#   'longitudeE7': 1268791749,
#   'centerLatE7': 374349395,
#   'centerLngE7': 1268793411,
#   'name': '스타벅스 광명소하DT점',
#   'address': '대한민국 경기도 광명시 소하동 1077'},
#  {'placeId': 'ChIJiWKXIGxhezURSdDzm8-jpb0',
#   'locationConfidence': 64.059875,
#   'startTimestamp': '2022-07-31T02:35:12.966Z',
#   'endTimestamp': '2022-08-01T07:42:57.386Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374308554,
#   'longitudeE7': 1268842593,
#   'centerLatE7': 374308540,
#   'centerLngE7': 1268842945,
#   'name': '501 광명역세권휴먼시아5단지',
#   'address': '대한민국 광명시 소하2동'},
#  {'placeId': 'ChIJif2a9EFhezURHkD8egX3ht0',
#   'locationConfidence': 92.76103,
#   'startTimestamp': '2022-06-01T04:09:25.241Z',
#   'endTimestamp': '2022-06-01T04:25:43.246Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374245517,
#   'longitudeE7': 1268842226,
#   'centerLatE7': 374240258,
#   'centerLngE7': 1268845429,
#   'name': 'LOTTE Mall Gwangmyeong',
#   'address': '대한민국 경기도 광명시 일직로 17'},
#  {'placeId': 'ChIJiWKXIGxhezURSdDzm8-jpb0',
#   'locationConfidence': 59.260548,
#   'startTimestamp': '2022-06-01T04:36:48.439Z',
#   'endTimestamp': '2022-06-01T09:06:40.297Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374308554,
#   'longitudeE7': 1268842593,
#   'centerLatE7': 374308324,
#   'centerLngE7': 1268841548,
#   'name': '501 광명역세권휴먼시아5단지',
#   'address': '대한민국 광명시 소하2동'},
#  {'placeId': 'ChIJWej-f19hezUR9FDKpNTwbO8',
#   'locationConfidence': 85.387825,
#   'startTimestamp': '2022-06-01T09:56:20.747Z',
#   'endTimestamp': '2022-06-01T10:02:06.770Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374283937,
#   'longitudeE7': 1268680943,
#   'centerLatE7': 374271775,
#   'centerLngE7': 1268704800,
#   'name': 'Gahagsan',
#   'address': '대한민국 경기도 광명시 소하동 산132-2'},
#  {'placeId': 'ChIJiWKXIGxhezURSdDzm8-jpb0',
#   'locationConfidence': 74.06647,
#   'startTimestamp': '2022-06-01T10:21:24.945Z',
#   'endTimestamp': '2022-06-02T23:14:19.100Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374308554,
#   'longitudeE7': 1268842593,
#   'centerLatE7': 374308519,
#   'centerLngE7': 1268841385,
#   'name': '501 광명역세권휴먼시아5단지',
#   'address': '대한민국 광명시 소하2동'},
#  {'placeId': 'ChIJ3Sey7a-ofDURam8Ne0dOt3A',
#   'locationConfidence': 24.226772,
#   'startTimestamp': '2022-06-02T23:56:19Z',
#   'endTimestamp': '2022-06-03T03:36:30.471Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374543291,
#   'longitudeE7': 1271354574,
#   'centerLatE7': 374552468,
#   'centerLngE7': 1271341155,
#   'name': '가천대학교 기숙사',
#   'address': '대한민국 성남시 복정동'},
#  {'placeId': 'ChIJ3QtO1eKnfDURCvgaST3sO-o',
#   'locationConfidence': 98.571815,
#   'startTimestamp': '2022-06-03T04:10:10.600Z',
#   'endTimestamp': '2022-06-03T05:05:51.856Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374456961,
#   'longitudeE7': 1270574552,
#   'centerLatE7': 374456807,
#   'centerLngE7': 1270575771,
#   'name': '부안애서',
#   'address': '대한민국 서울특별시 서초구 내곡동 청계산로 223'},
#  {'placeId': 'ChIJLfEW1c6nfDURpvA7T_7CHtA',
#   'locationConfidence': 98.99509,
#   'startTimestamp': '2022-06-03T05:11:16.172Z',
#   'endTimestamp': '2022-06-03T06:17:04.685Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374486053,
#   'longitudeE7': 1270585206,
#   'centerLatE7': 374486241,
#   'centerLngE7': 1270585981,
#   'name': 'Second Clock',
#   'address': '대한민국 서울특별시 서초구 내곡동 청룡마을길 41'},
#  {'placeId': 'ChIJiWKXIGxhezURSdDzm8-jpb0',
#   'locationConfidence': 67.86739,
#   'startTimestamp': '2022-06-03T07:05:40.901Z',
#   'endTimestamp': '2022-06-03T09:35:45.623Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374308554,
#   'longitudeE7': 1268842593,
#   'centerLatE7': 374308515,
#   'centerLngE7': 1268842046,
#   'name': '501 광명역세권휴먼시아5단지',
#   'address': '대한민국 광명시 소하2동'},
#  {'placeId': 'ChIJif2a9EFhezURHkD8egX3ht0',
#   'locationConfidence': 91.93354,
#   'startTimestamp': '2022-06-03T10:30:55.883Z',
#   'endTimestamp': '2022-06-03T11:27:34.985Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374245517,
#   'longitudeE7': 1268842226,
#   'centerLatE7': 374236763,
#   'centerLngE7': 1268846244,
#   'name': 'LOTTE Mall Gwangmyeong',
#   'address': '대한민국 경기도 광명시 일직로 17'},
#  {'placeId': 'ChIJiWKXIGxhezURSdDzm8-jpb0',
#   'locationConfidence': 64.8156,
#   'startTimestamp': '2022-06-03T11:42:45.080Z',
#   'endTimestamp': '2022-06-04T03:13:18.090Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374308554,
#   'longitudeE7': 1268842593,
#   'centerLatE7': 374308778,
#   'centerLngE7': 1268840991,
#   'name': '501 광명역세권휴먼시아5단지',
#   'address': '대한민국 광명시 소하2동'},
#  {'placeId': 'ChIJN2zdnZ5hezUREl23D21bt6c',
#   'locationConfidence': 96.483116,
#   'startTimestamp': '2022-06-04T03:41:26.871Z',
#   'endTimestamp': '2022-06-04T04:59:28.989Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374466589,
#   'longitudeE7': 1268845654,
#   'centerLatE7': 374466346,
#   'centerLngE7': 1268845435,
#   'name': 'Emart Gwangmyeong Soha',
#   'address': '대한민국 경기도 광명시 소하동 소하로 97'},
#  {'placeId': 'ChIJiWKXIGxhezURSdDzm8-jpb0',
#   'locationConfidence': 58.217136,
#   'startTimestamp': '2022-06-04T05:14:24.065Z',
#   'endTimestamp': '2022-06-04T23:53:55.098Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374308554,
#   'longitudeE7': 1268842593,
#   'centerLatE7': 374308771,
#   'centerLngE7': 1268842050,
#   'name': '501 광명역세권휴먼시아5단지',
#   'address': '대한민국 광명시 소하2동'},
#  {'placeId': 'ChIJQQMYIeJjezURmjWlDv243gI',
#   'locationConfidence': 88.95047,
#   'startTimestamp': '2022-06-05T00:31:13.999Z',
#   'endTimestamp': '2022-06-05T01:08:48.323Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374264944,
#   'longitudeE7': 1268664843,
#   'centerLatE7': 374269220,
#   'centerLngE7': 1268646008,
#   'name': 'Gwangmyeong Cave',
#   'address': '대한민국 경기도 광명시 학온동 가학로85번길 142'},
#  {'placeId': 'ChIJiWKXIGxhezURSdDzm8-jpb0',
#   'locationConfidence': 68.42202,
#   'startTimestamp': '2022-06-05T01:50:53.271Z',
#   'endTimestamp': '2022-06-05T11:24:14.518Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374308554,
#   'longitudeE7': 1268842593,
#   'centerLatE7': 374308932,
#   'centerLngE7': 1268840600,
#   'name': '501 광명역세권휴먼시아5단지',
#   'address': '대한민국 광명시 소하2동'},
#  {'placeId': 'ChIJiWKXIGxhezURSdDzm8-jpb0',
#   'locationConfidence': 65.849396,
#   'startTimestamp': '2022-06-05T11:50:01.043Z',
#   'endTimestamp': '2022-06-06T00:46:01.841Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374308554,
#   'longitudeE7': 1268842593,
#   'centerLatE7': 374309120,
#   'centerLngE7': 1268841351,
#   'name': '501 광명역세권휴먼시아5단지',
#   'address': '대한민국 광명시 소하2동'},
#  {'placeId': 'ChIJVwJW829hezURambBObg3Tn4',
#   'locationConfidence': 95.63656,
#   'startTimestamp': '2022-06-06T01:00:08.672Z',
#   'endTimestamp': '2022-06-06T05:14:35Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374348248,
#   'longitudeE7': 1268791749,
#   'centerLatE7': 374349204,
#   'centerLngE7': 1268793836,
#   'name': '스타벅스 광명소하DT점',
#   'address': '대한민국 경기도 광명시 소하동 1077'},
#  {'placeId': 'ChIJiWKXIGxhezURSdDzm8-jpb0',
#   'locationConfidence': 66.277916,
#   'startTimestamp': '2022-06-06T05:21:28.609Z',
#   'endTimestamp': '2022-06-06T08:43:26.722Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374308554,
#   'longitudeE7': 1268842593,
#   'centerLatE7': 374309294,
#   'centerLngE7': 1268841328,
#   'name': '501 광명역세권휴먼시아5단지',
#   'address': '대한민국 광명시 소하2동'},
#  {'placeId': 'ChIJiWKXIGxhezURSdDzm8-jpb0',
#   'locationConfidence': 66.43297,
#   'startTimestamp': '2022-06-06T10:26:00.267Z',
#   'endTimestamp': '2022-06-07T22:54:55.887Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374308554,
#   'longitudeE7': 1268842593,
#   'centerLatE7': 374307695,
#   'centerLngE7': 1268841531,
#   'name': '501 광명역세권휴먼시아5단지',
#   'address': '대한민국 광명시 소하2동'},
#  {'placeId': 'ChIJiWKXIGxhezURSdDzm8-jpb0',
#   'locationConfidence': 53.926678,
#   'startTimestamp': '2022-06-07T23:45:20.479Z',
#   'endTimestamp': '2022-06-08T09:16:06.698Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374308554,
#   'longitudeE7': 1268842593,
#   'centerLatE7': 374308914,
#   'centerLngE7': 1268842312,
#   'name': '501 광명역세권휴먼시아5단지',
#   'address': '대한민국 광명시 소하2동'},
#  {'placeId': 'ChIJ_6chamhhezURQfOZsReDjBU',
#   'locationConfidence': 31.608374,
#   'startTimestamp': '2022-06-08T10:04:34.445Z',
#   'endTimestamp': '2022-06-08T10:46:23.390Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374325969,
#   'longitudeE7': 1268798556,
#   'centerLatE7': 374326991,
#   'centerLngE7': 1268800350,
#   'name': '국수나무 광명충현점',
#   'address': '대한민국 경기도 광명시 성채로 50번길 9-11 101호'},
#  {'placeId': 'ChIJiWKXIGxhezURSdDzm8-jpb0',
#   'locationConfidence': 66.447495,
#   'startTimestamp': '2022-06-08T11:01:55.644Z',
#   'endTimestamp': '2022-06-09T00:47:11.233Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374308554,
#   'longitudeE7': 1268842593,
#   'centerLatE7': 374309250,
#   'centerLngE7': 1268841040,
#   'name': '501 광명역세권휴먼시아5단지',
#   'address': '대한민국 광명시 소하2동'},
#  {'placeId': 'ChIJEzxZfkZhezURBF7hCxWG7Qk',
#   'locationConfidence': 28.155725,
#   'startTimestamp': '2022-06-09T01:09:37.732Z',
#   'endTimestamp': '2022-06-09T01:41:49.437Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374175170,
#   'longitudeE7': 1268843230,
#   'centerLatE7': 374177700,
#   'centerLngE7': 1268846974,
#   'name': 'KTX광명역1번출구',
#   'address': '대한민국 광명시'},
#  {'placeId': 'ChIJn5eRaL1hezURoGHUwdAFqsI',
#   'locationConfidence': 93.702736,
#   'startTimestamp': '2022-06-09T01:48:58.631Z',
#   'endTimestamp': '2022-06-09T04:12:29.591Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374189097,
#   'longitudeE7': 1268828764,
#   'centerLatE7': 374188484,
#   'centerLngE7': 1268828282,
#   'name': 'AK플라자 광명점',
#   'address': '대한민국 경기도 광명시 일직동 양지로 17'},
#  {'placeId': 'ChIJ-SUOB0RhezURJ9gVWW0ChyI',
#   'locationConfidence': 52.9504,
#   'startTimestamp': '2022-06-09T04:13:08.864Z',
#   'endTimestamp': '2022-06-09T04:54:43.819Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374203252,
#   'longitudeE7': 1268837534,
#   'centerLatE7': 374204315,
#   'centerLngE7': 1268837245,
#   'name': '컬러테크',
#   'address': '대한민국 경기도 광명시 신기로 21'},
#  {'placeId': 'ChIJiWKXIGxhezURSdDzm8-jpb0',
#   'locationConfidence': 62.434196,
#   'startTimestamp': '2022-06-09T05:08:33.585Z',
#   'endTimestamp': '2022-06-10T03:15:15.880Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374308554,
#   'longitudeE7': 1268842593,
#   'centerLatE7': 374308656,
#   'centerLngE7': 1268841724,
#   'name': '501 광명역세권휴먼시아5단지',
#   'address': '대한민국 광명시 소하2동'},
#  {'placeId': 'ChIJEy2xgJ6ffDURJr2FD_LNqqM',
#   'locationConfidence': 29.388275,
#   'startTimestamp': '2022-06-10T03:51:10.054Z',
#   'endTimestamp': '2022-06-10T06:16:19.392Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 375352957,
#   'longitudeE7': 1268788394,
#   'centerLatE7': 375352853,
#   'centerLngE7': 1268791084,
#   'name': '스타벅스 목동파리공원점',
#   'address': '대한민국 서울특별시 양천구 목동 907-18'},
#  {'placeId': 'ChIJiWKXIGxhezURSdDzm8-jpb0',
#   'locationConfidence': 46.478893,
#   'startTimestamp': '2022-06-10T07:01:31.480Z',
#   'endTimestamp': '2022-06-10T09:04:08.245Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374308554,
#   'longitudeE7': 1268842593,
#   'centerLatE7': 374309290,
#   'centerLngE7': 1268841348,
#   'name': '501 광명역세권휴먼시아5단지',
#   'address': '대한민국 광명시 소하2동'},
#  {'placeId': 'ChIJ3Ucr1mhhezURah8-ewzEiIc',
#   'locationConfidence': 51.589798,
#   'startTimestamp': '2022-06-10T09:07:01.446Z',
#   'endTimestamp': '2022-06-10T10:11:50.558Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374301291,
#   'longitudeE7': 1268817984,
#   'centerLatE7': 374292812,
#   'centerLngE7': 1268818646,
#   'name': '충현중학교',
#   'address': '대한민국 경기도 광명시 소하2동 서원로 42'},
#  {'placeId': 'ChIJiWKXIGxhezURSdDzm8-jpb0',
#   'locationConfidence': 68.7599,
#   'startTimestamp': '2022-06-10T10:14:21.614Z',
#   'endTimestamp': '2022-06-10T10:36:22.623Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374308554,
#   'longitudeE7': 1268842593,
#   'centerLatE7': 374305445,
#   'centerLngE7': 1268841100,
#   'name': '501 광명역세권휴먼시아5단지',
#   'address': '대한민국 광명시 소하2동'},
#  {'placeId': 'ChIJiWKXIGxhezURSdDzm8-jpb0',
#   'locationConfidence': 58.05128,
#   'startTimestamp': '2022-06-10T11:12:06.799Z',
#   'endTimestamp': '2022-06-11T09:44:29.839Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374308554,
#   'longitudeE7': 1268842593,
#   'centerLatE7': 374307385,
#   'centerLngE7': 1268842248,
#   'name': '501 광명역세권휴먼시아5단지',
#   'address': '대한민국 광명시 소하2동'},
#  {'placeId': 'ChIJU3Blq4JhezURJLN9nb5PlNc',
#   'locationConfidence': 36.19351,
#   'startTimestamp': '2022-06-11T09:57:19.487Z',
#   'endTimestamp': '2022-06-11T11:50:12.702Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374211574,
#   'longitudeE7': 1268831407,
#   'centerLatE7': 374213157,
#   'centerLngE7': 1268832783,
#   'name': '오유미당(광명KTX점)',
#   'address': '대한민국 경기도 광명시 일직동 139'},
#  {'placeId': 'ChIJiWKXIGxhezURSdDzm8-jpb0',
#   'locationConfidence': 70.12545,
#   'startTimestamp': '2022-06-11T12:11:34.432Z',
#   'endTimestamp': '2022-06-12T00:48:24.330Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374308554,
#   'longitudeE7': 1268842593,
#   'centerLatE7': 374308461,
#   'centerLngE7': 1268841532,
#   'name': '501 광명역세권휴먼시아5단지',
#   'address': '대한민국 광명시 소하2동'},
#  {'placeId': 'ChIJQQMYIeJjezURmjWlDv243gI',
#   'locationConfidence': 89.07979,
#   'startTimestamp': '2022-06-12T01:24:13.999Z',
#   'endTimestamp': '2022-06-12T02:12:11Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374264944,
#   'longitudeE7': 1268664843,
#   'centerLatE7': 374270579,
#   'centerLngE7': 1268643489,
#   'name': 'Gwangmyeong Cave',
#   'address': '대한민국 경기도 광명시 학온동 가학로85번길 142'},
#  {'placeId': 'ChIJiWKXIGxhezURSdDzm8-jpb0',
#   'locationConfidence': 64.08585,
#   'startTimestamp': '2022-06-12T02:44:43.616Z',
#   'endTimestamp': '2022-06-13T06:52:21.679Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374308554,
#   'longitudeE7': 1268842593,
#   'centerLatE7': 374308093,
#   'centerLngE7': 1268842050,
#   'name': '501 광명역세권휴먼시아5단지',
#   'address': '대한민국 광명시 소하2동'},
#  {'placeId': 'ChIJkT4EGUFhezURmFNNjUBhZdw',
#   'locationConfidence': 93.71843,
#   'startTimestamp': '2022-06-13T07:02:20.089Z',
#   'endTimestamp': '2022-06-13T07:57:37.291Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374206838,
#   'longitudeE7': 1268864277,
#   'centerLatE7': 374210319,
#   'centerLngE7': 1268858438,
#   'name': 'Costco Wholesale - Gwangmyeong Branch',
#   'address': '대한민국 경기도 광명시 일직로 40'},
#  {'placeId': 'ChIJiWKXIGxhezURSdDzm8-jpb0',
#   'locationConfidence': 69.39879,
#   'startTimestamp': '2022-06-13T08:18:39.140Z',
#   'endTimestamp': '2022-06-13T22:30:42.029Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374308554,
#   'longitudeE7': 1268842593,
#   'centerLatE7': 374308248,
#   'centerLngE7': 1268842035,
#   'name': '501 광명역세권휴먼시아5단지',
#   'address': '대한민국 광명시 소하2동'},
#  {'placeId': 'ChIJAbUX_WZhezUR3tMOiyitnso',
#   'locationConfidence': 89.69222,
#   'startTimestamp': '2022-06-13T22:39:41.428Z',
#   'endTimestamp': '2022-06-13T22:47:14.303Z',
#   'placeVisitImportance': 'TRANSITIONAL',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374304200,
#   'longitudeE7': 1268756150,
#   'centerLatE7': 374305800,
#   'centerLngE7': 1268752967,
#   'name': 'Soha-dong Gwangmyeong Cave Entrance',
#   'address': '대한민국 광명시'},
#  {'placeId': 'ChIJiWKXIGxhezURSdDzm8-jpb0',
#   'locationConfidence': 56.168694,
#   'startTimestamp': '2022-06-13T23:02:47.836Z',
# ...
#   'locationConfidence': 64.87988,
#   'startTimestamp': '2022-05-21T03:07:03.747Z',
#   'endTimestamp': '2022-05-21T10:14:39.529Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374308554,
#   'longitudeE7': 1268842593,
#   'centerLatE7': 374309077,
#   'centerLngE7': 1268842362,
#   'name': '501 광명역세권휴먼시아5단지',
#   'address': '대한민국 광명시 소하2동'},
#  {'placeId': 'ChIJif2a9EFhezURHkD8egX3ht0',
#   'locationConfidence': 37.104904,
#   'startTimestamp': '2022-05-21T10:38:32.999Z',
#   'endTimestamp': '2022-05-21T11:52:22.161Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374245517,
#   'longitudeE7': 1268842226,
#   'centerLatE7': 374236190,
#   'centerLngE7': 1268861329,
#   'name': 'LOTTE Mall Gwangmyeong',
#   'address': '대한민국 경기도 광명시 일직로 17'},
#  {'placeId': 'ChIJiWKXIGxhezURSdDzm8-jpb0',
#   'locationConfidence': 67.22078,
#   'startTimestamp': '2022-05-21T11:58:03.522Z',
#   'endTimestamp': '2022-05-22T00:00:18.526Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374308554,
#   'longitudeE7': 1268842593,
#   'centerLatE7': 374308394,
#   'centerLngE7': 1268841856,
#   'name': '501 광명역세권휴먼시아5단지',
#   'address': '대한민국 광명시 소하2동'},
#  {'placeId': 'ChIJiWKXIGxhezURSdDzm8-jpb0',
#   'locationConfidence': 55.708515,
#   'startTimestamp': '2022-05-22T00:21:48.094Z',
#   'endTimestamp': '2022-05-22T01:57:50.524Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374308554,
#   'longitudeE7': 1268842593,
#   'centerLatE7': 374309052,
#   'centerLngE7': 1268841458,
#   'name': '501 광명역세권휴먼시아5단지',
#   'address': '대한민국 광명시 소하2동'},
#  {'placeId': 'ChIJkT4EGUFhezURmFNNjUBhZdw',
#   'locationConfidence': 42.114372,
#   'startTimestamp': '2022-05-22T02:23:37.449Z',
#   'endTimestamp': '2022-05-22T03:25:36.058Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374206838,
#   'longitudeE7': 1268864277,
#   'centerLatE7': 374233972,
#   'centerLngE7': 1268862028,
#   'name': 'Costco Wholesale - Gwangmyeong Branch',
#   'address': '대한민국 경기도 광명시 일직로 40'},
#  {'placeId': 'ChIJn5eRaL1hezURoGHUwdAFqsI',
#   'locationConfidence': 97.59829,
#   'startTimestamp': '2022-05-22T03:35:57.484Z',
#   'endTimestamp': '2022-05-22T07:24:15.402Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374189097,
#   'longitudeE7': 1268828764,
#   'centerLatE7': 374187671,
#   'centerLngE7': 1268829391,
#   'name': 'AK플라자 광명점',
#   'address': '대한민국 경기도 광명시 일직동 양지로 17'},
#  {'placeId': 'ChIJif2a9EFhezURHkD8egX3ht0',
#   'locationConfidence': 94.26348,
#   'startTimestamp': '2022-05-22T07:33:44.654Z',
#   'endTimestamp': '2022-05-22T07:48:59.210Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374245517,
#   'longitudeE7': 1268842226,
#   'centerLatE7': 374237886,
#   'centerLngE7': 1268848214,
#   'name': 'LOTTE Mall Gwangmyeong',
#   'address': '대한민국 경기도 광명시 일직로 17'},
#  {'placeId': 'ChIJiWKXIGxhezURSdDzm8-jpb0',
#   'locationConfidence': 67.89088,
#   'startTimestamp': '2022-05-22T08:00:18.822Z',
#   'endTimestamp': '2022-05-22T23:44:40.394Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374308554,
#   'longitudeE7': 1268842593,
#   'centerLatE7': 374308585,
#   'centerLngE7': 1268842149,
#   'name': '501 광명역세권휴먼시아5단지',
#   'address': '대한민국 광명시 소하2동'},
#  {'placeId': 'ChIJiVLUtRFeezURKOznbSv--R4',
#   'locationConfidence': 39.409416,
#   'startTimestamp': '2022-05-23T00:26:12Z',
#   'endTimestamp': '2022-05-23T01:37:13Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 373865844,
#   'longitudeE7': 1269678645,
#   'centerLatE7': 373861370,
#   'centerLngE7': 1269685048,
#   'name': '꿈마을라이프아파트',
#   'address': '대한민국 경기도 안양시 동안구 귀인동 932-6'},
#  {'placeId': 'ChIJnSqsGHBeezURADQ4BgKhJFA',
#   'locationConfidence': 38.06603,
#   'startTimestamp': '2022-05-23T01:46:05Z',
#   'endTimestamp': '2022-05-23T05:07:57.999Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 373786633,
#   'longitudeE7': 1269851233,
#   'centerLatE7': 373787760,
#   'centerLngE7': 1269850286,
#   'name': '일출보리밥',
#   'address': '대한민국 경기도 의왕시 손골길 17'},
#  {'placeId': 'ChIJiWKXIGxhezURSdDzm8-jpb0',
#   'locationConfidence': 60.0239,
#   'startTimestamp': '2022-05-23T05:51:35.525Z',
#   'endTimestamp': '2022-05-23T22:54:17.929Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374308554,
#   'longitudeE7': 1268842593,
#   'centerLatE7': 374308998,
#   'centerLngE7': 1268841567,
#   'name': '501 광명역세권휴먼시아5단지',
#   'address': '대한민국 광명시 소하2동'},
#  {'placeId': 'ChIJiWKXIGxhezURSdDzm8-jpb0',
#   'locationConfidence': 58.91159,
#   'startTimestamp': '2022-05-24T00:17:54Z',
#   'endTimestamp': '2022-05-24T01:21:04.440Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374308554,
#   'longitudeE7': 1268842593,
#   'centerLatE7': 374309024,
#   'centerLngE7': 1268841645,
#   'name': '501 광명역세권휴먼시아5단지',
#   'address': '대한민국 광명시 소하2동'},
#  {'placeId': 'ChIJvcc68DWhfDURLY5igJuPLEk',
#   'locationConfidence': 39.22139,
#   'startTimestamp': '2022-05-24T02:06:26.782Z',
#   'endTimestamp': '2022-05-24T04:07:05.597Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374878705,
#   'longitudeE7': 1270156390,
#   'centerLatE7': 374878763,
#   'centerLngE7': 1270155650,
#   'name': 'SSO-OK',
#   'address': '대한민국 서울특별시 서초구 서초동 1625-10 1층'},
#  {'placeId': 'ChIJDWIToGyhfDUR-reHnAcvtaE',
#   'locationConfidence': 55.10866,
#   'startTimestamp': '2022-05-24T04:14:08.760Z',
#   'endTimestamp': '2022-05-24T07:14:15.027Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374866068,
#   'longitudeE7': 1270159074,
#   'centerLatE7': 374865935,
#   'centerLngE7': 1270157461,
#   'name': '하우덴코리아(유한)',
#   'address': '대한민국 서울특별시 서초구 서초중앙로8길 7'},
#  {'placeId': 'ChIJiWKXIGxhezURSdDzm8-jpb0',
#   'locationConfidence': 58.984196,
#   'startTimestamp': '2022-05-24T08:05:03.124Z',
#   'endTimestamp': '2022-05-24T22:57:32.907Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374308554,
#   'longitudeE7': 1268842593,
#   'centerLatE7': 374308845,
#   'centerLngE7': 1268841951,
#   'name': '501 광명역세권휴먼시아5단지',
#   'address': '대한민국 광명시 소하2동'},
#  {'placeId': 'ChIJiWKXIGxhezURSdDzm8-jpb0',
#   'locationConfidence': 55.76319,
#   'startTimestamp': '2022-05-25T00:12:09Z',
#   'endTimestamp': '2022-05-25T04:12:32Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374308554,
#   'longitudeE7': 1268842593,
#   'centerLatE7': 374308992,
#   'centerLngE7': 1268841676,
#   'name': '501 광명역세권휴먼시아5단지',
#   'address': '대한민국 광명시 소하2동'},
#  {'placeId': 'ChIJrV2JUeNhezURUjjXsgtj574',
#   'locationConfidence': 26.708693,
#   'startTimestamp': '2022-05-25T04:36:29.955Z',
#   'endTimestamp': '2022-05-25T08:50:06.057Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374235655,
#   'longitudeE7': 1268862723,
#   'centerLatE7': 374234054,
#   'centerLngE7': 1268860791,
#   'name': '싸이오닉',
#   'address': '대한민국 경기도 광명시 일직로 43 GIDC A동 2606호'},
#  {'placeId': 'ChIJif2a9EFhezURHkD8egX3ht0',
#   'locationConfidence': 89.06867,
#   'startTimestamp': '2022-05-25T08:57:15.335Z',
#   'endTimestamp': '2022-05-25T09:11:12.873Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374245517,
#   'longitudeE7': 1268842226,
#   'centerLatE7': 374239237,
#   'centerLngE7': 1268847538,
#   'name': 'LOTTE Mall Gwangmyeong',
#   'address': '대한민국 경기도 광명시 일직로 17'},
#  {'placeId': 'ChIJiWKXIGxhezURSdDzm8-jpb0',
#   'locationConfidence': 57.75052,
#   'startTimestamp': '2022-05-25T09:18:44.961Z',
#   'endTimestamp': '2022-05-26T08:21:06.568Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374308554,
#   'longitudeE7': 1268842593,
#   'centerLatE7': 374308686,
#   'centerLngE7': 1268840884,
#   'name': '501 광명역세권휴먼시아5단지',
#   'address': '대한민국 광명시 소하2동'},
#  {'placeId': 'ChIJif2a9EFhezURHkD8egX3ht0',
#   'locationConfidence': 94.19506,
#   'startTimestamp': '2022-05-26T08:28:40.115Z',
#   'endTimestamp': '2022-05-26T08:37:42.894Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374245517,
#   'longitudeE7': 1268842226,
#   'centerLatE7': 374238811,
#   'centerLngE7': 1268845711,
#   'name': 'LOTTE Mall Gwangmyeong',
#   'address': '대한민국 경기도 광명시 일직로 17'},
#  {'placeId': 'ChIJiWKXIGxhezURSdDzm8-jpb0',
#   'locationConfidence': 61.095016,
#   'startTimestamp': '2022-05-26T08:49:08.924Z',
#   'endTimestamp': '2022-05-26T23:19:28.061Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374308554,
#   'longitudeE7': 1268842593,
#   'centerLatE7': 374307535,
#   'centerLngE7': 1268842268,
#   'name': '501 광명역세권휴먼시아5단지',
#   'address': '대한민국 광명시 소하2동'},
#  {'placeId': 'ChIJme_OoK-ofDUR1blHbiLexyE',
#   'locationConfidence': 35.758812,
#   'startTimestamp': '2022-05-27T00:05:49.999Z',
#   'endTimestamp': '2022-05-27T03:25:17.844Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374555718,
#   'longitudeE7': 1271340122,
#   'centerLatE7': 374552520,
#   'centerLngE7': 1271342087,
#   'name': None,
#   'address': '대한민국 경기도 성남시 수정구 복정동 산77'},
#  {'placeId': 'ChIJn5eRaL1hezURoGHUwdAFqsI',
#   'locationConfidence': 97.51237,
#   'startTimestamp': '2022-05-27T04:20:33.117Z',
#   'endTimestamp': '2022-05-27T04:56:20.070Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374189097,
#   'longitudeE7': 1268828764,
#   'centerLatE7': 374182666,
#   'centerLngE7': 1268826681,
#   'name': 'AK플라자 광명점',
#   'address': '대한민국 경기도 광명시 일직동 양지로 17'},
#  {'placeId': 'ChIJiWKXIGxhezURSdDzm8-jpb0',
#   'locationConfidence': 66.93918,
#   'startTimestamp': '2022-05-27T05:08:18.184Z',
#   'endTimestamp': '2022-05-27T08:29:51Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374308554,
#   'longitudeE7': 1268842593,
#   'centerLatE7': 374308104,
#   'centerLngE7': 1268841538,
#   'name': '501 광명역세권휴먼시아5단지',
#   'address': '대한민국 광명시 소하2동'},
#  {'placeId': 'ChIJiWKXIGxhezURSdDzm8-jpb0',
#   'locationConfidence': 58.263237,
#   'startTimestamp': '2022-05-27T09:56:02.999Z',
#   'endTimestamp': '2022-05-27T22:34:47.754Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374308554,
#   'longitudeE7': 1268842593,
#   'centerLatE7': 374309367,
#   'centerLngE7': 1268839386,
#   'name': '501 광명역세권휴먼시아5단지',
#   'address': '대한민국 광명시 소하2동'},
#  {'placeId': 'ChIJ1Wf3E3phezUR7tR759eYiLo',
#   'locationConfidence': 81.6632,
#   'startTimestamp': '2022-05-27T22:37:03.645Z',
#   'endTimestamp': '2022-05-27T22:49:02.181Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374320718,
#   'longitudeE7': 1268801051,
#   'centerLatE7': 374322086,
#   'centerLngE7': 1268804929,
#   'name': 'Soha 2-dong Community Service Center',
#   'address': '대한민국 경기도 광명시 소하2동 성채로 52'},
#  {'placeId': 'ChIJxV6uLA7GejURMs8M-AjFvaA',
#   'locationConfidence': 95.610565,
#   'startTimestamp': '2022-05-28T00:44:27.493Z',
#   'endTimestamp': '2022-05-28T01:06:23.112Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 365711276,
#   'longitudeE7': 1271121651,
#   'centerLatE7': 365708833,
#   'centerLngE7': 1271122633,
#   'name': 'Jeongan Service Area',
#   'address': '대한민국 충청남도 공주시 정안면 논산천안고속도로 57-1'},
#  {'placeId': 'ChIJSwE_P1A7cDUR61oVx-prd4o',
#   'locationConfidence': 99.234695,
#   'startTimestamp': '2022-05-28T02:25:30.732Z',
#   'endTimestamp': '2022-05-28T03:20:07.546Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 358197151,
#   'longitudeE7': 1271171649,
#   'centerLatE7': 358197548,
#   'centerLngE7': 1271170211,
#   'name': '현대옥 전주본점',
#   'address': '대한민국 전라북도 전주시 중화산동2가 화산천변2길 7-4 KR'},
#  {'placeId': 'ChIJ7cYrwWMjcDURAuTCRbxvfhA',
#   'locationConfidence': 72.61568,
#   'startTimestamp': '2022-05-28T06:05:05.236Z',
#   'endTimestamp': '2022-05-28T06:56:55.359Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 358177903,
#   'longitudeE7': 1271538172,
#   'centerLatE7': 358177994,
#   'centerLngE7': 1271538500,
#   'name': '전주한옥마을전망대카페',
#   'address': '대한민국 전라북도 전주시 완산구 남노송동 98-13 KR'},
#  {'placeId': 'ChIJqYCoR9g8cDURBZv4awMXfws',
#   'locationConfidence': 97.72989,
#   'startTimestamp': '2022-05-28T07:14:01.031Z',
#   'endTimestamp': '2022-05-28T07:50:37Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 358652338,
#   'longitudeE7': 1271140095,
#   'centerLatE7': 358650170,
#   'centerLngE7': 1271137496,
#   'name': 'Honamgag',
#   'address': '대한민국 전라북도 전주시 덕진구 송천동2가 560-3 KR'},
#  {'placeId': 'ChIJ6601tRrGejURMVbZlQO4Qv8',
#   'locationConfidence': 92.490944,
#   'startTimestamp': '2022-05-28T08:44:41Z',
#   'endTimestamp': '2022-05-28T08:59:04.303Z',
#   'placeVisitImportance': 'TRANSITIONAL',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 365695196,
#   'longitudeE7': 1271150441,
#   'centerLatE7': 365701023,
#   'centerLngE7': 1271149074,
#   'name': 'Jeongan Service Area',
#   'address': '대한민국 충청남도 공주시 정안면 논산천안고속도로 58'},
#  {'placeId': 'ChIJiWKXIGxhezURSdDzm8-jpb0',
#   'locationConfidence': 53.257496,
#   'startTimestamp': '2022-05-28T10:39:06.175Z',
#   'endTimestamp': '2022-05-29T01:51:17.193Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374308554,
#   'longitudeE7': 1268842593,
#   'centerLatE7': 374309487,
#   'centerLngE7': 1268841587,
#   'name': '501 광명역세권휴먼시아5단지',
#   'address': '대한민국 광명시 소하2동'},
#  {'placeId': 'ChIJif2a9EFhezURHkD8egX3ht0',
#   'locationConfidence': 77.54561,
#   'startTimestamp': '2022-05-29T01:56:45.201Z',
#   'endTimestamp': '2022-05-29T03:56:54.116Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374245517,
#   'longitudeE7': 1268842226,
#   'centerLatE7': 374247216,
#   'centerLngE7': 1268843612,
#   'name': 'LOTTE Mall Gwangmyeong',
#   'address': '대한민국 경기도 광명시 일직로 17'},
#  {'placeId': 'ChIJe_OEVTZhezURZVZOKT15c9A',
#   'locationConfidence': 82.448265,
#   'startTimestamp': '2022-05-29T04:04:34.437Z',
#   'endTimestamp': '2022-05-29T04:56:10.241Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374242139,
#   'longitudeE7': 1268860203,
#   'centerLatE7': 374243728,
#   'centerLngE7': 1268865894,
#   'name': '중앙대학교광명병원',
#   'address': '대한민국 경기도 광명시 일직동 501'},
#  {'placeId': 'ChIJiWKXIGxhezURSdDzm8-jpb0',
#   'locationConfidence': 65.56504,
#   'startTimestamp': '2022-05-29T05:13:53.788Z',
#   'endTimestamp': '2022-05-30T00:23:38.362Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374308554,
#   'longitudeE7': 1268842593,
#   'centerLatE7': 374308513,
#   'centerLngE7': 1268841564,
#   'name': '501 광명역세권휴먼시아5단지',
#   'address': '대한민국 광명시 소하2동'},
#  {'placeId': 'ChIJkT4EGUFhezURmFNNjUBhZdw',
#   'locationConfidence': 93.71764,
#   'startTimestamp': '2022-05-30T00:52:54.475Z',
#   'endTimestamp': '2022-05-30T02:07:52.426Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374206838,
#   'longitudeE7': 1268864277,
#   'centerLatE7': 374208992,
#   'centerLngE7': 1268858954,
#   'name': 'Costco Wholesale - Gwangmyeong Branch',
#   'address': '대한민국 경기도 광명시 일직로 40'},
#  {'placeId': 'ChIJiWKXIGxhezURSdDzm8-jpb0',
#   'locationConfidence': 57.597305,
#   'startTimestamp': '2022-05-30T02:22:31.502Z',
#   'endTimestamp': '2022-05-30T09:50:19Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374308554,
#   'longitudeE7': 1268842593,
#   'centerLatE7': 374309658,
#   'centerLngE7': 1268840750,
#   'name': '501 광명역세권휴먼시아5단지',
#   'address': '대한민국 광명시 소하2동'},
#  {'placeId': 'ChIJiWKXIGxhezURSdDzm8-jpb0',
#   'locationConfidence': 48.73679,
#   'startTimestamp': '2022-05-30T10:50:56.788Z',
#   'endTimestamp': '2022-06-01T03:59:57.914Z',
#   'placeVisitImportance': 'MAIN',
#   'placeVisitType': 'SINGLE_PLACE',
#   'latitudeE7': 374308554,
#   'longitudeE7': 1268842593,
#   'centerLatE7': 374309204,
#   'centerLngE7': 1268841654,
#   'name': '501 광명역세권휴먼시아5단지',
#   'address': '대한민국 광명시 소하2동'}]

# %% [markdown]
# #### 4. DataFrame 형태로 변환하기

# %%
# 1.DataFrame형태로 변환하기
place_visits_df = pd.DataFrame(place_visits)
place_visits_df.head(2)


# 2.데이터 전처리하기
# convert to datetime type
place_visits_df["startTimestamp"] = pd.to_datetime(place_visits_df["startTimestamp"])
place_visits_df["endTimestamp"] = pd.to_datetime(place_visits_df["endTimestamp"])

# get geo coordinates as float value
place_visits_df["latitude"] = place_visits_df.latitudeE7/10**7   #(1E7 = 1e7 = 1x10^7 = 10**7)
place_visits_df["longitude"] = place_visits_df.longitudeE7/1e7
place_visits_df["centerLat"] = place_visits_df.centerLatE7/1E7
place_visits_df["centerLng"] = place_visits_df.centerLngE7/1E7
 
# add timezone based on geo coordinates
tf = TimezoneFinder()
place_visits_df["timezone"] = place_visits_df.apply(lambda row: tf.timezone_at(lng=row.longitude, lat=row.latitude), axis=1)

# convert UTC time to local timezone
place_visits_df['startTimestamp_local'] = place_visits_df.apply(lambda row: row.startTimestamp.tz_convert(row.timezone), axis=1)
place_visits_df['endTimestamp_local'] =place_visits_df.apply(lambda row: row.endTimestamp.tz_convert(row.timezone), axis=1)

# remove TZ info from datetime
place_visits_df['startTimestamp_local'] = pd.to_datetime(place_visits_df['startTimestamp_local'].apply(lambda x: x.replace(tzinfo=None)))
place_visits_df['endTimestamp_local'] = pd.to_datetime(place_visits_df['endTimestamp_local'].apply(lambda x: x.replace(tzinfo=None)))

# add datetime parts as a separate column to data frame
for datetime_type in [("year", lambda x: x.year), ("month", lambda x: x.month), ("day", lambda x: x.day), ("hour", lambda x: x.hour), ("minute", lambda x: x.minute), ("weekday", lambda x: x.weekday)]:
    for tztype in ["", "_local"]:
        place_visits_df[f"{datetime_type[0]}{tztype}"] = datetime_type[1](place_visits_df[f"startTimestamp{tztype}"].dt)
        

place_visits_df.drop(columns=["latitudeE7", "longitudeE7", "centerLatE7", "centerLngE7"], inplace=True)
place_visits_df["duration"] = place_visits_df.endTimestamp - place_visits_df.startTimestamp
place_visits_df["duration_minutes"] = place_visits_df.duration.dt.total_seconds()/60


# 3. 파일로 저장하기
file = "data/place_visits.csv"
place_visits_df.to_csv(file, index=False)


place_visits_df
# Out:
#                          placeId  locationConfidence  \
# 0    ChIJ-TPmtZ5hezUR_ynve8y3RN8           94.888380
# 1    ChIJiWKXIGxhezURSdDzm8-jpb0           71.795320
# 2    ChIJkT4EGUFhezURmFNNjUBhZdw           91.551320
# 3    ChIJiWKXIGxhezURSdDzm8-jpb0           70.120850
# 4    ChIJl4xz5DalfDUR5J-cZDd1bDM           87.759590
# ..                           ...                 ...
# 249  ChIJe_OEVTZhezURZVZOKT15c9A           82.448265
# 250  ChIJiWKXIGxhezURSdDzm8-jpb0           65.565040
# 251  ChIJkT4EGUFhezURmFNNjUBhZdw           93.717640
# 252  ChIJiWKXIGxhezURSdDzm8-jpb0           57.597305
# 253  ChIJiWKXIGxhezURSdDzm8-jpb0           48.736790
#
#                       startTimestamp                     endTimestamp  \
# 0   2022-08-01 07:58:34.215000+00:00 2022-08-01 08:44:38.168000+00:00
# 1   2022-08-01 09:21:21.989000+00:00 2022-08-02 08:39:53.052000+00:00
# 2   2022-08-02 08:54:19.849000+00:00 2022-08-02 09:47:05.617000+00:00
# 3   2022-08-02 10:03:04.965000+00:00 2022-08-02 18:20:28.867000+00:00
# 4   2022-07-02 02:07:57.776000+00:00 2022-07-02 08:29:09.583000+00:00
# ..                               ...                              ...
# 249 2022-05-29 04:04:34.437000+00:00 2022-05-29 04:56:10.241000+00:00
# 250 2022-05-29 05:13:53.788000+00:00 2022-05-30 00:23:38.362000+00:00
# 251 2022-05-30 00:52:54.475000+00:00 2022-05-30 02:07:52.426000+00:00
# 252 2022-05-30 02:22:31.502000+00:00        2022-05-30 09:50:19+00:00
# 253 2022-05-30 10:50:56.788000+00:00 2022-06-01 03:59:57.914000+00:00
#
#     placeVisitImportance placeVisitType  \
# 0                   MAIN   SINGLE_PLACE
# 1                   MAIN   SINGLE_PLACE
# 2                   MAIN   SINGLE_PLACE
# 3                   MAIN   SINGLE_PLACE
# 4                   MAIN   SINGLE_PLACE
# ..                   ...            ...
# 249                 MAIN   SINGLE_PLACE
# 250                 MAIN   SINGLE_PLACE
# 251                 MAIN   SINGLE_PLACE
# 252                 MAIN   SINGLE_PLACE
# 253                 MAIN   SINGLE_PLACE
#
#                                       name  \
# 0                                    개성손만두
# 1                         501 광명역세권휴먼시아5단지
# 2             Costco Wholesale Gwangmyeong
# 3                         501 광명역세권휴먼시아5단지
# 4                                     COEX
# ..                                     ...
# 249                              중앙대학교광명병원
# 250                       501 광명역세권휴먼시아5단지
# 251  Costco Wholesale - Gwangmyeong Branch
# 252                       501 광명역세권휴먼시아5단지
# 253                       501 광명역세권휴먼시아5단지
#
#                                  address   latitude   longitude  ...  day  \
# 0    대한민국 광명시 소하동 1337번지 103호 광명시 경기도 KR  37.447297  126.885489  ...    1
# 1                          대한민국 광명시 소하2동  37.430855  126.884259  ...    1
# 2                    대한민국 경기도 광명시 일직로 40  37.420856  126.885813  ...    2
# 3                          대한민국 광명시 소하2동  37.430855  126.884259  ...    2
# 4                대한민국 서울특별시 강남구 영동대로 513  37.511683  127.059151  ...    2
# ..                                   ...        ...         ...  ...  ...
# 249                 대한민국 경기도 광명시 일직동 501  37.424214  126.886020  ...   29
# 250                        대한민국 광명시 소하2동  37.430855  126.884259  ...   29
# 251                  대한민국 경기도 광명시 일직로 40  37.420684  126.886428  ...   30
# 252                        대한민국 광명시 소하2동  37.430855  126.884259  ...   30
# 253                        대한민국 광명시 소하2동  37.430855  126.884259  ...   30
#
#      day_local hour hour_local minute  minute_local  weekday  weekday_local  \
# 0            1    7         16     58            58        0              0
# 1            1    9         18     21            21        0              0
# 2            2    8         17     54            54        1              1
# 3            2   10         19      3             3        1              1
# 4            2    2         11      7             7        5              5
# ..         ...  ...        ...    ...           ...      ...            ...
# 249         29    4         13      4             4        6              6
# 250         29    5         14     13            13        6              6
# 251         30    0          9     52            52        0              0
# 252         30    2         11     22            22        0              0
# 253         30   10         19     50            50        0              0
#
#                   duration  duration_minutes
# 0   0 days 00:46:03.953000         46.065883
# 1   0 days 23:18:31.063000       1398.517717
# 2   0 days 00:52:45.768000         52.762800
# 3   0 days 08:17:23.902000        497.398367
# 4   0 days 06:21:11.807000        381.196783
# ..                     ...               ...
# 249 0 days 00:51:35.804000         51.596733
# 250 0 days 19:09:44.574000       1149.742900
# 251 0 days 01:14:57.951000         74.965850
# 252 0 days 07:27:47.498000        447.791633
# 253 1 days 17:09:01.126000       2469.018767
#
# [254 rows x 29 columns]

# %% [markdown]
# #### 5. (나의)Location History 지도에 표시하기

# %%
import folium
import webbrowser
import pandas as pd

# 파일 불러오기
# df = pd.read_csv(file)
df = place_visits_df


center = [37.4306881, 126.8845086]
# m = folium.Map(location=center ,
#                   zoom_start=6, 
#                   width=750, 
#                   height=500)
m = folium.Map(location=center ,
                  zoom_start=6)

# df에서 위도&경도 정보 지도 Marker에 추가하기
folium.Marker(location=center, 
                popup='우리집', icon=folium.Icon(color='red', icon='star'),
                color='tomato', radius = 50,
).add_to(m)


# 구글 Location History 마커로 표시하기
for i, row in df.iterrows():    
    folium.Marker(location= [row['latitude'], row['longitude']], 
                  icon=folium.Icon(icon='cloud', color='green'),
                  popup=row['name']
    ).add_to(m)
    
m    

#html 파일로 저장하여 불러오기
m.save('data/map_google_lh.html')
webbrowser.open('C:/python/projectmanager/data/map_google_lh.html')
# Out:
# True

# %% [markdown]
# --------------------

# %% [markdown]
# ### 우리나라 행정구역 경계 지도에 표시하기

# %% [markdown]
# ####  1. 우리나라 행정구역 경계 데이터 다운로드하기
# - https://github.com/southkorea/southkorea-maps  > /kostat/2018/json/
# - **Provinces (시도)** :  skorea-provinces-2018-geo.json
# - **Municipalities (시군구)** : skorea-municipalities-2018-geo.json

# %% [markdown]
# #### 2. 우리나라 행정구역 시/도 경계 표시하기

# %%
import folium
import json


file = 'data/geo/skorea-provinces-2018-geo.json'          # 대한민국 시도 행정구역
# file = 'data/skorea-municipalities-2018-geo.json'   # 대한민국 시군구 
# file = 'data/skorea-submunicipalities-2018-geo.json'       # 대한민국 시군구 읍면동
rfile = open(file, 'r', encoding='utf-8').read()
jsonData = json.loads(rfile)

m = folium.Map(location=[37.566345, 126.977893], zoom_start=6)
folium.GeoJson(jsonData, name='json_data').add_to(m)
m

import webbrowser

m.save('data/map_provinces.html')
webbrowser.open('c:/python/projectmanager/data/map_provinces.html') # fullpath를 사용해야 오류가 없다
# Out:
# True

# %% [markdown]
# -----------

# %% [markdown]
# ### [실습] 서울지역 시군구/ 인구수 지도에 시각화하기

# %% [markdown]
# ### 1. 데이터 준비하기 ( 서울지역 행정구역 데이터)
#
#
# |구분 | geocode데이터(json) | 인구 데이터(csv) |
# |:----|:----|:----|
# |다운로드 |https://github.com/raqoon886/Local_HangJeongDong    |https://jumin.mois.go.kr/index.jsp |
# |파일명 |hangjeongdong_서울특별시.geojson <br> seoul_municipalities_geo_simple.json | 202205_202205_주민등록인구및세대현황_월간_서울.csv|
# |URL |https://raw.githubusercontent.com/southkorea/seoul-maps/master/kostat/2013/json/seoul_municipalities_geo_simple.json | |

# %%
#----------------------------
### 1. 데이터 준비하기
#----------------------------

import pandas as pd

file = 'data/geo/202205_202205_주민등록인구및세대현황_월간_서울.csv'
df = pd.read_csv(file, encoding='euc-kr')
df_t = df.copy()
df_t.head()


#----------------------------
### 2. 데이터 전처리하기
#----------------------------
# 불필요한 행 제거
df_t.drop( [df_t.index[0]], inplace=True  ) # 첫째행 삭제

# 불필요한 열 제거
df_t.drop( ['2022년05월_세대수','2022년05월_세대당 인구','2022년05월_남여 비율'], 
               axis=1, inplace=True ) # 특정 컬럼 삭제

# 컬럼명 변경
df_t.columns = ['행정구역','total','man','woman']
df_t.head(2)


# 행정구역 시, 군 분리하기
# 특정 위치에 컬럼 추가
df_t.insert(1, 'sido', df_t['행정구역'].str.split(' ').str[0]) # 인덱스 1 위치에 추가
df_t.insert(2, 'name', df_t['행정구역'].str.split(' ').str[1]) # 인덱스 2 위치에 추가

# 맨 뒤에 컬럼 추가
# df_t['시'] = df_t['행정구역'].str.split(' ').str[0]
# df_t['군'] = df_t['행정구역'].str.split(' ').str[1]

# 숫자안에 콤마 제거 
df_t['total'] = df_t['total'].str.replace(pat=r',', repl=r'', regex=True)
df_t['man'] = df_t['man'].str.replace(pat=r',', repl=r'', regex=True)
df_t['woman'] = df_t['woman'].str.replace(pat=r',', repl=r'', regex=True)

# 최종 불필요한 컬럼 제거
df_t.drop( ['행정구역'], axis=1, inplace=True ) # 특정 컬럼 삭제
df_t.head(2)

# 파일로 저장하기
file = 'data/geo/서울시_행정구역별_인구-m.csv'
df_t.to_csv(file)


#----------------------------
### 3. 지도에 표시하기
#----------------------------

import pandas as pd

# 행정구역별 인구 데이터 불러오기.
df = pd.read_csv(file)
df.drop(['Unnamed: 0'], axis = 1, inplace = True)


# 방법1: 행정구역별 Geocode 데이터 불러오기-
geo_data = 'https://raw.githubusercontent.com/southkorea/seoul-maps/master/kostat/2013/json/seoul_municipalities_geo_simple.json'

# 방법2: 행정구역별 Geocode 데이터 불러오기 - 
# import json
# file = 'data/geo/seoul_municipalities_geo_simple.json'
# with open(file, 'r', encoding='utf-8') as f:
#     geo_data = json.load(f)
    
geo_data


# 자도에 표시하기
import folium

# 서울시 중심부의 위도, 경도 입니다.
center = [37.541, 126.986]

# 맵이 center 에 위치하고, zoom 레벨은 11로 시작하는 맵 m을 만듭니다.
m = folium.Map(location=center, tiles="OpenStreetMap", zoom_start=10)

#Choropleth 레이어를 만들고, 맵 m에 추가합니다.
folium.Choropleth(
    geo_data=geo_data,
    name='인구수',
    data=df,
    columns=('name', 'total'),
    key_on='feature.properties.name',
    fill_color='YlGn',
    legend_name='total',
).add_to(m)

# 맵 m을 출력합니다.
m

import webbrowser
m.save('data/seoul_provinces.html')
webbrowser.open('c:/python/projectmanager/data/seoul_provinces.html') # fullpath를 사용해야 오류가 없다
# Out:
# True

# %% [markdown]
# ### [실습문제] 서울시 읍면동 시각화하기
# - 행정구역 인구수: 202205_202205_주민등록인구및세대현황_월간_전국_읍면동.csv (2022년)
# - geojson지도정보: seoul_submunicipalities_geo_simple.json (2013년)

# %%
#--------------------
### 1. 데이터 준비하기
#--------------------
import pandas as pd

file = 'data/geo/202207_202207_주민등록인구및세대현황_월간_전국_읍면동.csv'
df = pd.read_csv(file, encoding='euc-kr')
df_t = df.copy()
df_t = df.query(" 행정구역.str.contains('서울특별시') ")
df_t.head()

#--------------------
### 2. 데이터 전처리
#--------------------
# 불필요한 행 제거
df_t.drop( [df_t.index[0]], inplace=True  ) # 첫째행 삭제

# 불필요한 열 제거
df_t.drop( ['2022년07월_세대수','2022년07월_세대당 인구','2022년07월_남여 비율'], 
               axis=1, inplace=True ) # 특정 컬럼 삭제


# 컬럼명 변경
df_t.columns = ['행정구역','total','man','woman']
df_t.head(2)


# 행정구역 시, 군 분리하기
# 특정 위치에 컬럼 추가
df_t.insert(1, 'sido', df_t['행정구역'].str.split(' ').str[0]) # 인덱스 1 위치에 추가
df_t.insert(2, 'gugun', df_t['행정구역'].str.split(' ').str[1]) # 인덱스 2 위치에 추가
df_t.insert(3, 'name', df_t['행정구역'].str.split(' ').str[2]) # 인덱스 3 위치에 추가
df_t['name'] = df_t['name'].str.split('(').str[0].str.strip()

# 숫자안에 콤마 제거 
df_t['total'] = df_t['total'].str.replace(pat=r',', repl=r'', regex=True)
df_t['man'] = df_t['man'].str.replace(pat=r',', repl=r'', regex=True)
df_t['woman'] = df_t['woman'].str.replace(pat=r',', repl=r'', regex=True)

# 최종 불필요한 컬럼 제거
df_t.drop( ['행정구역'], axis=1, inplace=True ) # 특정 컬럼 삭제
df_t.dropna(subset=['name'], inplace=True)  # null인 데이터 삭제
df_t = df_t.query(" name != '' ")

# 파일로 저장하기
file = 'data/geo/서울시_행정구역별_읍면동_인구-m.csv'
df_t.to_csv(file)
df_t


#--------------------
### 3. 지도에 표시하기
#--------------------
import pandas as pd

# 행정구역별 인구 데이터 불러오기.
df = pd.read_csv(file)
df.drop(['Unnamed: 0'], axis = 1, inplace = True)


# 행정구역별 Geocode 데이터 불러오기 - # 방법2 (동 단위까지 있는 지리정보)
import json
file = 'data/geo/seoul_submunicipalities_geo_simple.json'
with open(file, 'r', encoding='utf-8') as f:
    geo_data = json.load(f)
    
geo_data




import folium

# 서울시 중심부의 위도, 경도 입니다.
center = [37.541, 126.986]

# 맵이 center 에 위치하고, zoom 레벨은 11로 시작하는 맵 m을 만듭니다.
m = folium.Map(location=center, tiles="OpenStreetMap", zoom_start=10)

#Choropleth 레이어를 만들고, 맵 m에 추가합니다.
folium.Choropleth(
    geo_data=geo_data,
    name='인구수',
    data=df,
    columns=('name', 'total'),
    key_on='feature.properties.name',
    fill_color='YlOrRd',
    legend_name='total',
).add_to(m)

# 맵 m을 출력합니다.
m  

import webbrowser
m.save('data/seoul_detail_provinces.html')
webbrowser.open('c:/python/projectmanager/data/seoul_detail_provinces.html') # fullpath를 사용해야 오류가 없다
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_12144\2842084924.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_t.drop( [df_t.index[0]], inplace=True  ) # 첫째행 삭제
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_12144\2842084924.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_t.drop( ['2022년07월_세대수','2022년07월_세대당 인구','2022년07월_남여 비율'],
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_12144\2842084924.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_t['name'] = df_t['name'].str.split('(').str[0].str.strip()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_12144\2842084924.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_t['total'] = df_t['total'].str.replace(pat=r',', repl=r'', regex=True)
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_12144\2842084924.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_t['man'] = df_t['man'].str.replace(pat=r',', repl=r'', regex=True)
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_12144\2842084924.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_t['woman'] = df_t['woman'].str.replace(pat=r',', repl=r'', regex=True)
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_12144\2842084924.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_t.drop( ['행정구역'], axis=1, inplace=True ) # 특정 컬럼 삭제
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_12144\2842084924.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_t.dropna(subset=['name'], inplace=True)  # null인 데이터 삭제
# True

# %% [markdown]
# ### [실습문제] 제주도 행정구역정보 이용하여 지도 영역 표시하기
#
# - https://github.com/southkorea/southkorea-maps/tree/master/kostat/2013/json
# - 행정구역 인구수: 202207_202207_주민등록인구및세대현황_월간_제주.csv
# - geojson지도정보: skorea_municipalities_geo_simple-jeju.json

# %%
#----------------------------
### 1. 데이터 준비하기
#----------------------------

import pandas as pd

file = 'data/geo/202207_202207_주민등록인구및세대현황_월간_제주.csv'
df = pd.read_csv(file, encoding='euc-kr')
df_t = df.copy()
df_t.head()


#----------------------------
### 2. 데이터 전처리하기
#----------------------------
# 불필요한 행 제거
df_t.drop( [df_t.index[0]], inplace=True  ) # 첫째행 삭제

# 불필요한 열 제거
df_t.drop( ['2022년07월_세대수','2022년07월_세대당 인구','2022년07월_남여 비율'], 
               axis=1, inplace=True ) # 특정 컬럼 삭제

# 컬럼명 변경
df_t.columns = ['행정구역','total','man','woman']
df_t.head(2)


# 행정구역 시, 군 분리하기
# 특정 위치에 컬럼 추가
df_t.insert(1, 'sido', df_t['행정구역'].str.split(' ').str[0]) # 인덱스 1 위치에 추가
df_t.insert(2, 'name', df_t['행정구역'].str.split(' ').str[1]) # 인덱스 2 위치에 추가

# 맨 뒤에 컬럼 추가
# df_t['시'] = df_t['행정구역'].str.split(' ').str[0]
# df_t['군'] = df_t['행정구역'].str.split(' ').str[1]

# 숫자안에 콤마 제거 
df_t['total'] = df_t['total'].str.replace(pat=r',', repl=r'', regex=True)
df_t['man'] = df_t['man'].str.replace(pat=r',', repl=r'', regex=True)
df_t['woman'] = df_t['woman'].str.replace(pat=r',', repl=r'', regex=True)

# 최종 불필요한 컬럼 제거
df_t.drop( ['행정구역'], axis=1, inplace=True ) # 특정 컬럼 삭제
df_t.head(2)

# 파일로 저장하기
file = 'data/geo/제주_행정구역별_인구-m.csv'
df_t.to_csv(file)


#----------------------------
### 3. 지도에 표시하기
#----------------------------

import pandas as pd

# 행정구역별 인구 데이터 불러오기.
df = pd.read_csv(file)
df.drop(['Unnamed: 0'], axis = 1, inplace = True)


# 행정구역별 Geocode 데이터 불러오기-방법1
# geo_data = 'https://raw.githubusercontent.com/southkorea/southkorea-maps/master/kostat/2013/json/skorea_municipalities_geo_simple.json'

# 행정구역별 Geocode 데이터 불러오기 - # 방법2 (동 단위까지 있는 지리정보)
import json
file = 'data/geo/jeju_municipalities_geo_simple.json'
with open(file, 'r', encoding='utf-8') as f:
    geo_data = json.load(f)

# 자도에 표시하기
import folium

# 서울시 중심부의 위도, 경도 입니다.
center = [33.446958, 126.5678683]

# 맵이 center 에 위치하고, zoom 레벨은 11로 시작하는 맵 m을 만듭니다.
m = folium.Map(location=center, tiles="OpenStreetMap", zoom_start=8)


#Choropleth 레이어를 만들고, 맵 m에 추가합니다.
folium.Choropleth(
    geo_data=geo_data,
    name='인구수',
    data=df,
    columns=('name', 'total'),
    key_on='feature.properties.name',
    fill_color='YlGn',
    legend_name='total',
).add_to(m)

# 맵 m을 출력합니다.
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_caa19800af0caa13ac337bfa10c4afee {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_caa19800af0caa13ac337bfa10c4afee&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_caa19800af0caa13ac337bfa10c4afee = L.map(
#                 &quot;map_caa19800af0caa13ac337bfa10c4afee&quot;,
#                 {
#                     center: [33.446958, 126.5678683],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4fe04693eb9f5fce79a0640fa4284310 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_caa19800af0caa13ac337bfa10c4afee);
#
#
#             var choropleth_2e03924d54523a8198d082244abe1c2f = L.featureGroup(
#                 {}
#             ).addTo(map_caa19800af0caa13ac337bfa10c4afee);
#
#
#         function geo_json_eae236c1809fa8431337205757b4d1e8_styler(feature) {
#             switch(feature.properties.code) {
#                 case &quot;39010&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#006837&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffcc&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_eae236c1809fa8431337205757b4d1e8_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_eae236c1809fa8431337205757b4d1e8 = L.geoJson(null, {
#                 onEachFeature: geo_json_eae236c1809fa8431337205757b4d1e8_onEachFeature,
#
#                 style: geo_json_eae236c1809fa8431337205757b4d1e8_styler,
#         });
#
#         function geo_json_eae236c1809fa8431337205757b4d1e8_add (data) {
#             geo_json_eae236c1809fa8431337205757b4d1e8
#                 .addData(data)
#                 .addTo(choropleth_2e03924d54523a8198d082244abe1c2f);
#         }
#             geo_json_eae236c1809fa8431337205757b4d1e8_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[126.1701670531016, 33.27833920373795], [126.17796199822318, 33.28904450342792], [126.20366562455006, 33.292582069125935], [126.23227804627976, 33.28054651709448], [126.27081469983565, 33.29305651947374], [126.28692516789717, 33.3095121006344], [126.32582807936741, 33.32307849544494], [126.33863040850332, 33.33700002289742], [126.37692773779688, 33.34348978209229], [126.42008790072302, 33.33448285889923], [126.43967991919219, 33.34042205120408], [126.44742456956253, 33.35529267692266], [126.4918716225209, 33.351283204155564], [126.54001194569452, 33.35949354681064], [126.55310458705854, 33.368769331336765], [126.5830715764017, 33.368027779973275], [126.65655971322707, 33.39658294968576], [126.68911351796443, 33.39691133705054], [126.70784071345439, 33.41819831436605], [126.73472429940135, 33.422146338653775], [126.75951968887561, 33.41497179862364], [126.79074582138537, 33.43825351998022], [126.82385785054652, 33.44338028367965], [126.8898274152664, 33.47823603716075], [126.90529687529418, 33.480086403367224], [126.91451306461225, 33.46996423390579], [126.93834260748045, 33.47055272752707], [126.91017277435895, 33.402610687558585], [126.90919306806411, 33.3879255679562], [126.87535882585192, 33.36822409322237], [126.8705501162605, 33.34975159885652], [126.84671810776004, 33.33005904428782], [126.83805963301805, 33.30541883125935], [126.81058128765947, 33.29810905802241], [126.78058721090692, 33.30348117728641], [126.74744517061241, 33.27477917807315], [126.69397491052028, 33.26589785324775], [126.66139509103422, 33.26764883602634], [126.64370899012728, 33.26176379473827], [126.62124671799259, 33.238001461003755], [126.60023270919079, 33.23253794499945], [126.58793276547512, 33.24078903556731], [126.55000275643071, 33.233994617394124], [126.52287888872885, 33.237410624439875], [126.5112182224236, 33.226741039104716], [126.47233571972863, 33.219241198557235], [126.45245786615838, 33.23676200849374], [126.43326944303328, 33.22862021392413], [126.41456422346796, 33.24077765309614], [126.38663415314419, 33.2281960784446], [126.32186188505729, 33.2348134021202], [126.29961093191966, 33.219470994774156], [126.29462959454436, 33.20325737472914], [126.27360444082919, 33.19065258266024], [126.2344607950971, 33.231192587887506], [126.20182608174507, 33.242644947267415], [126.18421578146823, 33.2556336839387], [126.1701670531016, 33.27833920373795]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;39020&quot;, &quot;name&quot;: &quot;\uc11c\uadc0\ud3ec\uc2dc&quot;, &

# %% [markdown]
# ------------------------------------
